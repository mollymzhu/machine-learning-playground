# %% [markdown]
# # Improvise a Jazz Solo with an LSTM Network
#
# We will implement a model that uses an LSTM to generate music.
# **Steps:**
# - Apply an LSTM to music generation.
# - Generate your own jazz music with deep learning.

# %%
from __future__ import print_function
import IPython
import sys
from music21 import *
import numpy as np
from grammar import *
from qa import *
from preprocess import * 
from music_utils import *
from data_utils import *
from keras.models import load_model, Model
from keras.layers import Dense, Activation, Dropout, Input, LSTM, Reshape, Lambda, RepeatVector
from keras.initializers import glorot_uniform
from keras.utils import to_categorical
from keras.optimizers import Adam
from keras import backend as K
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## 1 - Problem statement
#
# We will train a network to generate novel jazz solos in a style representative of a body of performed work.
#
#
# ### 1.1 - Dataset
#
# Run the cell below to listen to a snippet of the audio from the training set:

# %%
IPython.display.Audio('./data/30s_seq.mp3')
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Our music generation system will use 78 unique values. Run the following code to load the raw music data and preprocess it into values. This might take a few minutes.

# %%
X, Y, n_values, indices_values = load_music_utils()
print('shape of X:', X.shape)
print('number of training examples:', X.shape[0])
print('Tx (length of sequence):', X.shape[1])
print('total # of unique values:', n_values)
print('Shape of Y:', Y.shape)
# Out:
# shape of X: (60, 30, 78)
# number of training examples: 60
# Tx (length of sequence): 30
# total # of unique values: 78
# Shape of Y: (30, 60, 78)

# %% [markdown]
# Data is loaded as follows:
#
# - `X`: This is an (m, $T_x$, 78) dimensional array. We have m training examples, each of which is a snippet of $T_x =30$ musical values. At each time step, the input is one of 78 different possible values, represented as a one-hot vector. Thus for example, X[i,t,:] is a one-hot vector representating the value of the i-th example at time t.
#
# - `Y`: This is essentially the same as `X`, but shifted one step to the left (to the past). Similar to the dinosaurus assignment, we're interested in the network using the previous values to predict the next value, so our sequence model will try to predict $y^{\langle t \rangle}$ given $x^{\langle 1\rangle}, \ldots, x^{\langle t \rangle}$. However, the data in `Y` is reordered to be dimension $(T_y, m, 78)$, where $T_y = T_x$. This format makes it more convenient to feed to the LSTM later.
#
# - `n_values`: The number of unique values in this dataset. This should be 78.
#
# - `indices_values`: python dictionary mapping from 0-77 to musical values.

# %% [markdown]
# ### 1.2 - Overview of our model
#
#
# We will be training the model on random snippets of 30 values taken from a much longer piece of music. Thus, we won't bother to set the first input $x^{\langle 1 \rangle} = \vec{0}$, which we had done previously to denote the start of a dinosaur name, since now most of these snippets of audio start somewhere in the middle of a piece of music. We are setting each of the snippts to have the same length $T_x = 30$ to make vectorization easier.

# %% [markdown]
# ## 2 - Building the model
#
# We will build and train a model that will learn musical patterns. To do so, you will need to build a model that takes in X of shape $(m, T_x, 78)$ and Y of shape $(T_y, m, 78)$. We will use an LSTM with 64 dimensional hidden states. Lets set `n_a = 64`.

# %%
n_a = 64

# %% [markdown]
# Here's how you can create a Keras model with multiple inputs and outputs. If you're building an RNN where even at test time entire input sequence $x^{\langle 1 \rangle}, x^{\langle 2 \rangle}, \ldots, x^{\langle T_x \rangle}$ were *given in advance*, for example if the inputs were words and the output was a label, then Keras has simple built-in functions to build the model. However, for sequence generation, at test time we don't know all the values of $x^{\langle t\rangle}$ in advance; instead we generate them one at a time using $x^{\langle t\rangle} = y^{\langle t-1 \rangle}$. So the code will be a bit more complicated, and you'll need to implement your own for-loop to iterate over the different time steps.
#
# The function `djmodel()` will call the LSTM layer $T_x$ times using a for-loop, and it is important that all $T_x$ copies have the same weights. I.e., it should not re-initiaiize the weights every time---the $T_x$ steps should have shared weights. The key steps for implementing layers with shareable weights in Keras are:
# 1. Define the layer objects (we will use global variables for this).
# 2. Call these objects when propagating the input.

# %%
reshapor = Reshape((1, 78))                        # Used in Step 2.B of djmodel(), below
LSTM_cell = LSTM(n_a, return_state = True)         # Used in Step 2.C
densor = Dense(n_values, activation='softmax')     # Used in Step 2.D

# %%
def djmodel(Tx, n_a, n_values):
    """
    Implement the model
    
    Arguments:
    Tx -- length of the sequence in a corpus
    n_a -- the number of activations used in our model
    n_values -- number of unique values in the music data 
    
    Returns:
    model -- a keras model with the 
    """
    
    # Define the input of your model with a shape 
    X = Input(shape=(Tx, n_values))
    
    # Define s0, initial hidden state for the decoder LSTM
    a0 = Input(shape=(n_a,), name='a0')
    c0 = Input(shape=(n_a,), name='c0')
    a = a0
    c = c0
    
    outputs = []
    
    for t in range(Tx):
        
        # select the "t"th time step vector from X. 
        x = Lambda(lambda x: X[:,t,:])(X)
        # Use reshapor to reshape x to be (1, n_values) (≈1 line)
        x = reshapor(x)
        # Perform one step of the LSTM_cell
        a, _, c = LSTM_cell(x, initial_state=[a, c])
        # Apply densor to the hidden state output of LSTM_Cell
        out = densor(a)
        # add the output to "outputs"
        outputs.append(out)
        
    model = Model(inputs = [X, a0, c0], outputs = outputs)
    
    return model

# %% [markdown]
# Run the following cell to define your model. We will use `Tx=30`, `n_a=64` (the dimension of the LSTM activations), and `n_values=78`. This cell may take a few seconds to run.

# %%
model = djmodel(Tx = 30 , n_a = 64, n_values = 78)

# %% [markdown]
# You now need to compile your model to be trained. We will Adam and a categorical cross-entropy loss.

# %%
opt = Adam(lr=0.01, beta_1=0.9, beta_2=0.999, decay=0.01)

model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# Finally, lets initialize `a0` and `c0` for the LSTM's initial state to be zero.

# %%
m = 60
a0 = np.zeros((m, n_a))
c0 = np.zeros((m, n_a))

# %% [markdown]
# Lets now fit the model! We will turn `Y` to a list before doing so, since the cost function expects `Y` to be provided in this format (one list item per time-step). So `list(Y)` is a list with 30 items, where each of the list items is of shape (60,78). Lets train for 100 epochs. This will take a few minutes.

# %%
model.fit([X, a0, c0], list(Y), epochs=100)
# Out:
# Epoch 1/100
# 60/60 [==============================] - 16s 265ms/step - loss: 125.8198 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.0000e+00 - dense_1_acc_1: 0.0500 - dense_1_acc_2: 0.1167 - dense_1_acc_3: 0.0167 - dense_1_acc_4: 0.0500 - dense_1_acc_5: 0.0500 - dense_1_acc_6: 0.0500 - dense_1_acc_7: 0.1000 - dense_1_acc_8: 0.0167 - dense_1_acc_9: 0.1000 - dense_1_acc_10: 0.0500 - dense_1_acc_11: 0.0667 - dense_1_acc_12: 0.0833 - dense_1_acc_13: 0.0833 - dense_1_acc_14: 0.0833 - dense_1_acc_15: 0.0167 - dense_1_acc_16: 0.0833 - dense_1_acc_17: 0.0167 - dense_1_acc_18: 0.0833 - dense_1_acc_19: 0.0500 - dense_1_acc_20: 0.0167 - dense_1_acc_21: 0.0500 - dense_1_acc_22: 0.0333 - dense_1_acc_23: 0.1000 - dense_1_acc_24: 0.0667 - dense_1_acc_25: 0.1167 - dense_1_acc_26: 0.0667 - dense_1_acc_27: 0.0833 - dense_1_acc_28: 0.0833 - dense_1_acc_29: 0.0333
# Epoch 2/100
# 60/60 [==============================] - 0s 2ms/step - loss: 122.8105 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.0333 - dense_1_acc_1: 0.2333 - dense_1_acc_2: 0.2500 - dense_1_acc_3: 0.1167 - dense_1_acc_4: 0.2167 - dense_1_acc_5: 0.1333 - dense_1_acc_6: 0.2500 - dense_1_acc_7: 0.3000 - dense_1_acc_8: 0.2000 - dense_1_acc_9: 0.2167 - dense_1_acc_10: 0.1333 - dense_1_acc_11: 0.2000 - dense_1_acc_12: 0.1833 - dense_1_acc_13: 0.2000 - dense_1_acc_14: 0.1833 - dense_1_acc_15: 0.1833 - dense_1_acc_16: 0.2167 - dense_1_acc_17: 0.1833 - dense_1_acc_18: 0.1667 - dense_1_acc_19: 0.2000 - dense_1_acc_20: 0.1667 - dense_1_acc_21: 0.1833 - dense_1_acc_22: 0.1667 - dense_1_acc_23: 0.1500 - dense_1_acc_24: 0.1333 - dense_1_acc_25: 0.2833 - dense_1_acc_26: 0.1167 - dense_1_acc_27: 0.2167 - dense_1_acc_28: 0.2167 - dense_1_acc_29: 0.0000e+00
# Epoch 3/100
# 60/60 [==============================] - 0s 2ms/step - loss: 116.8340 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.0333 - dense_1_acc_1: 0.3000 - dense_1_acc_2: 0.2667 - dense_1_acc_3: 0.1667 - dense_1_acc_4: 0.2000 - dense_1_acc_5: 0.1000 - dense_1_acc_6: 0.2167 - dense_1_acc_7: 0.3167 - dense_1_acc_8: 0.1000 - dense_1_acc_9: 0.1500 - dense_1_acc_10: 0.1667 - dense_1_acc_11: 0.1333 - dense_1_acc_12: 0.1333 - dense_1_acc_13: 0.1167 - dense_1_acc_14: 0.1500 - dense_1_acc_15: 0.1000 - dense_1_acc_16: 0.1333 - dense_1_acc_17: 0.1333 - dense_1_acc_18: 0.1333 - dense_1_acc_19: 0.0667 - dense_1_acc_20: 0.0667 - dense_1_acc_21: 0.1167 - dense_1_acc_22: 0.0833 - dense_1_acc_23: 0.0667 - dense_1_acc_24: 0.1167 - dense_1_acc_25: 0.1167 - dense_1_acc_26: 0.0833 - dense_1_acc_27: 0.1500 - dense_1_acc_28: 0.0500 - dense_1_acc_29: 0.0000e+00
# Epoch 4/100
# 60/60 [==============================] - 0s 2ms/step - loss: 112.5249 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.0833 - dense_1_acc_1: 0.2667 - dense_1_acc_2: 0.2500 - dense_1_acc_3: 0.1333 - dense_1_acc_4: 0.2333 - dense_1_acc_5: 0.1667 - dense_1_acc_6: 0.0833 - dense_1_acc_7: 0.2167 - dense_1_acc_8: 0.1667 - dense_1_acc_9: 0.1833 - dense_1_acc_10: 0.1667 - dense_1_acc_11: 0.0667 - dense_1_acc_12: 0.1167 - dense_1_acc_13: 0.1500 - dense_1_acc_14: 0.1000 - dense_1_acc_15: 0.1167 - dense_1_acc_16: 0.1667 - dense_1_acc_17: 0.0667 - dense_1_acc_18: 0.1167 - dense_1_acc_19: 0.1167 - dense_1_acc_20: 0.0833 - dense_1_acc_21: 0.0667 - dense_1_acc_22: 0.0167 - dense_1_acc_23: 0.0333 - dense_1_acc_24: 0.0833 - dense_1_acc_25: 0.1167 - dense_1_acc_26: 0.0667 - dense_1_acc_27: 0.0667 - dense_1_acc_28: 0.1167 - dense_1_acc_29: 0.0000e+00
# Epoch 5/100
# 60/60 [==============================] - 0s 2ms/step - loss: 108.2662 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.1000 - dense_1_acc_1: 0.2667 - dense_1_acc_2: 0.2333 - dense_1_acc_3: 0.1833 - dense_1_acc_4: 0.2167 - dense_1_acc_5: 0.1333 - dense_1_acc_6: 0.0667 - dense_1_acc_7: 0.2167 - dense_1_acc_8: 0.1667 - dense_1_acc_9: 0.1667 - dense_1_acc_10: 0.1167 - dense_1_acc_11: 0.0667 - dense_1_acc_12: 0.1500 - dense_1_acc_13: 0.1333 - dense_1_acc_14: 0.1333 - dense_1_acc_15: 0.1167 - dense_1_acc_16: 0.1833 - dense_1_acc_17: 0.0833 - dense_1_acc_18: 0.1333 - dense_1_acc_19: 0.1167 - dense_1_acc_20: 0.1000 - dense_1_acc_21: 0.0833 - dense_1_acc_22: 0.1000 - dense_1_acc_23: 0.0833 - dense_1_acc_24: 0.0500 - dense_1_acc_25: 0.1833 - dense_1_acc_26: 0.0667 - dense_1_acc_27: 0.1500 - dense_1_acc_28: 0.1000 - dense_1_acc_29: 0.0000e+00
# Epoch 6/100
# 60/60 [==============================] - 0s 2ms/step - loss: 105.5236 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.1000 - dense_1_acc_1: 0.1833 - dense_1_acc_2: 0.2167 - dense_1_acc_3: 0.2000 - dense_1_acc_4: 0.2167 - dense_1_acc_5: 0.1000 - dense_1_acc_6: 0.1167 - dense_1_acc_7: 0.2500 - dense_1_acc_8: 0.2167 - dense_1_acc_9: 0.1667 - dense_1_acc_10: 0.1500 - dense_1_acc_11: 0.1000 - dense_1_acc_12: 0.1833 - dense_1_acc_13: 0.2000 - dense_1_acc_14: 0.1833 - dense_1_acc_15: 0.1333 - dense_1_acc_16: 0.1667 - dense_1_acc_17: 0.1167 - dense_1_acc_18: 0.1833 - dense_1_acc_19: 0.1000 - dense_1_acc_20: 0.1000 - dense_1_acc_21: 0.1833 - dense_1_acc_22: 0.0667 - dense_1_acc_23: 0.1333 - dense_1_acc_24: 0.0500 - dense_1_acc_25: 0.1833 - dense_1_acc_26: 0.1167 - dense_1_acc_27: 0.1000 - dense_1_acc_28: 0.0667 - dense_1_acc_29: 0.0000e+00
# Epoch 7/100
# 60/60 [==============================] - 0s 2ms/step - loss: 102.4277 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.1000 - dense_1_acc_1: 0.1667 - dense_1_acc_2: 0.2167 - dense_1_acc_3: 0.2000 - dense_1_acc_4: 0.2167 - dense_1_acc_5: 0.1167 - dense_1_acc_6: 0.1500 - dense_1_acc_7: 0.2667 - dense_1_acc_8: 0.2000 - dense_1_acc_9: 0.1833 - dense_1_acc_10: 0.2000 - dense_1_acc_11: 0.1333 - dense_1_acc_12: 0.2000 - dense_1_acc_13: 0.2000 - dense_1_acc_14: 0.2167 - dense_1_acc_15: 0.1167 - dense_1_acc_16: 0.1000 - dense_1_acc_17: 0.1000 - dense_1_acc_18: 0.1833 - dense_1_acc_19: 0.0667 - dense_1_acc_20: 0.0833 - dense_1_acc_21: 0.1333 - dense_1_acc_22: 0.1167 - dense_1_acc_23: 0.1000 - dense_1_acc_24: 0.0500 - dense_1_acc_25: 0.2333 - dense_1_acc_26: 0.1000 - dense_1_acc_27: 0.1167 - dense_1_acc_28: 0.0667 - dense_1_acc_29: 0.0000e+00
# Epoch 8/100
# 60/60 [==============================] - 0s 2ms/step - loss: 99.3464 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.1000 - dense_1_acc_1: 0.1667 - dense_1_acc_2: 0.2167 - dense_1_acc_3: 0.2000 - dense_1_acc_4: 0.2167 - dense_1_acc_5: 0.1167 - dense_1_acc_6: 0.1500 - dense_1_acc_7: 0.2500 - dense_1_acc_8: 0.2167 - dense_1_acc_9: 0.1833 - dense_1_acc_10: 0.1667 - dense_1_acc_11: 0.1333 - dense_1_acc_12: 0.1667 - dense_1_acc_13: 0.2000 - dense_1_acc_14: 0.2000 - dense_1_acc_15: 0.1833 - dense_1_acc_16: 0.1667 - dense_1_acc_17: 0.1167 - dense_1_acc_18: 0.2167 - dense_1_acc_19: 0.1000 - dense_1_acc_20: 0.1167 - dense_1_acc_21: 0.1667 - dense_1_acc_22: 0.1333 - dense_1_acc_23: 0.1333 - dense_1_acc_24: 0.1000 - dense_1_acc_25: 0.2500 - dense_1_acc_26: 0.1000 - dense_1_acc_27: 0.1667 - dense_1_acc_28: 0.0833 - dense_1_acc_29: 0.0000e+00
# Epoch 9/100
# 60/60 [==============================] - 0s 2ms/step - loss: 95.9768 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.1000 - dense_1_acc_1: 0.1667 - dense_1_acc_2: 0.2333 - dense_1_acc_3: 0.2000 - dense_1_acc_4: 0.2333 - dense_1_acc_5: 0.1500 - dense_1_acc_6: 0.1833 - dense_1_acc_7: 0.2333 - dense_1_acc_8: 0.2167 - dense_1_acc_9: 0.1833 - dense_1_acc_10: 0.1667 - dense_1_acc_11: 0.1333 - dense_1_acc_12: 0.2167 - dense_1_acc_13: 0.1667 - dense_1_acc_14: 0.2000 - dense_1_acc_15: 0.1667 - dense_1_acc_16: 0.2167 - dense_1_acc_17: 0.1500 - dense_1_acc_18: 0.1833 - dense_1_acc_19: 0.1167 - dense_1_acc_20: 0.1333 - dense_1_acc_21: 0.1167 - dense_1_acc_22: 0.1000 - dense_1_acc_23: 0.1167 - dense_1_acc_24: 0.1000 - dense_1_acc_25: 0.2167 - dense_1_acc_26: 0.1333 - dense_1_acc_27: 0.1500 - dense_1_acc_28: 0.1500 - dense_1_acc_29: 0.0000e+00
# Epoch 10/100
# 60/60 [==============================] - 0s 2ms/step - loss: 93.0288 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.0667 - dense_1_acc_1: 0.1833 - dense_1_acc_2: 0.2500 - dense_1_acc_3: 0.2000 - dense_1_acc_4: 0.2167 - dense_1_acc_5: 0.1500 - dense_1_acc_6: 0.1667 - dense_1_acc_7: 0.2500 - dense_1_acc_8: 0.1667 - dense_1_acc_9: 0.1833 - dense_1_acc_10: 0.1833 - dense_1_acc_11: 0.1333 - dense_1_acc_12: 0.2000 - dense_1_acc_13: 0.2000 - dense_1_acc_14: 0.2333 - dense_1_acc_15: 0.1833 - dense_1_acc_16: 0.2333 - dense_1_acc_17: 0.1333 - dense_1_acc_18: 0.2333 - dense_1_acc_19: 0.1667 - dense_1_acc_20: 0.1333 - dense_1_acc_21: 0.1000 - dense_1_acc_22: 0.1333 - dense_1_acc_23: 0.1333 - dense_1_acc_24: 0.1667 - dense_1_acc_25: 0.3167 - dense_1_acc_26: 0.1333 - dense_1_acc_27: 0.2667 - dense_1_acc_28: 0.1500 - dense_1_acc_29: 0.0000e+00
# Epoch 11/100
# 60/60 [==============================] - 0s 2ms/step - loss: 88.7572 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.0667 - dense_1_acc_1: 0.1833 - dense_1_acc_2: 0.2500 - dense_1_acc_3: 0.2000 - dense_1_acc_4: 0.2333 - dense_1_acc_5: 0.1333 - dense_1_acc_6: 0.1833 - dense_1_acc_7: 0.2500 - dense_1_acc_8: 0.2500 - dense_1_acc_9: 0.2333 - dense_1_acc_10: 0.1833 - dense_1_acc_11: 0.1500 - dense_1_acc_12: 0.2833 - dense_1_acc_13: 0.2333 - dense_1_acc_14: 0.2167 - dense_1_acc_15: 0.2500 - dense_1_acc_16: 0.3000 - dense_1_acc_17: 0.1333 - dense_1_acc_18: 0.2833 - dense_1_acc_19: 0.3000 - dense_1_acc_20: 0.1667 - dense_1_acc_21: 0.2167 - dense_1_acc_22: 0.1833 - dense_1_acc_23: 0.1500 - dense_1_acc_24: 0.2000 - dense_1_acc_25: 0.3333 - dense_1_acc_26: 0.2167 - dense_1_acc_27: 0.2667 - dense_1_acc_28: 0.1667 - dense_1_acc_29: 0.0000e+00
# Epoch 12/100
# 60/60 [==============================] - 0s 2ms/step - loss: 85.4558 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.0667 - dense_1_acc_1: 0.1833 - dense_1_acc_2: 0.2500 - dense_1_acc_3: 0.2000 - dense_1_acc_4: 0.2500 - dense_1_acc_5: 0.1667 - dense_1_acc_6: 0.2000 - dense_1_acc_7: 0.3000 - dense_1_acc_8: 0.2667 - dense_1_acc_9: 0.2833 - dense_1_acc_10: 0.2000 - dense_1_acc_11: 0.2333 - dense_1_acc_12: 0.3667 - dense_1_acc_13: 0.2667 - dense_1_acc_14: 0.2500 - dense_1_acc_15: 0.2000 - dense_1_acc_16: 0.2333 - dense_1_acc_17: 0.2000 - dense_1_acc_18: 0.3000 - dense_1_acc_19: 0.2333 - dense_1_acc_20: 0.2167 - dense_1_acc_21: 0.2333 - dense_1_acc_22: 0.2500 - dense_1_acc_23: 0.2167 - dense_1_acc_24: 0.1333 - dense_1_acc_25: 0.3500 - dense_1_acc_26: 0.2667 - dense_1_acc_27: 0.2833 - dense_1_acc_28: 0.2000 - dense_1_acc_29: 0.0000e+00
# Epoch 13/100
# 60/60 [==============================] - 0s 2ms/step - loss: 82.3281 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.0667 - dense_1_acc_1: 0.1500 - dense_1_acc_2: 0.2500 - dense_1_acc_3: 0.2000 - dense_1_acc_4: 0.2500 - dense_1_acc_5: 0.1667 - dense_1_acc_6: 0.2500 - dense_1_acc_7: 0.2667 - dense_1_acc_8: 0.2333 - dense_1_acc_9: 0.2833 - dense_1_acc_10: 0.1833 - dense_1_acc_11: 0.2000 - dense_1_acc_12: 0.3000 - dense_1_acc_13: 0.2667 - dense_1_acc_14: 0.2833 - dense_1_acc_15: 0.2000 - dense_1_acc_16: 0.2167 - dense_1_acc_17: 0.1667 - dense_1_acc_18: 0.3167 - dense_1_acc_19: 0.2333 - dense_1_acc_20: 0.2167 - dense_1_acc_21: 0.2167 - dense_1_acc_22: 0.2500 - dense_1_acc_23: 0.2167 - dense_1_acc_24: 0.2333 - dense_1_acc_25: 0.3333 - dense_1_acc_26: 0.2000 - dense_1_acc_27: 0.3333 - dense_1_acc_28: 0.2167 - dense_1_acc_29: 0.0000e+00
# Epoch 14/100
# 60/60 [==============================] - 0s 2ms/step - loss: 78.7979 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.0667 - dense_1_acc_1: 0.1500 - dense_1_acc_2: 0.2667 - dense_1_acc_3: 0.2333 - dense_1_acc_4: 0.2833 - dense_1_acc_5: 0.1833 - dense_1_acc_6: 0.2667 - dense_1_acc_7: 0.3000 - dense_1_acc_8: 0.2167 - dense_1_acc_9: 0.2667 - dense_1_acc_10: 0.2667 - dense_1_acc_11: 0.1500 - dense_1_acc_12: 0.3167 - dense_1_acc_13: 0.3500 - dense_1_acc_14: 0.3333 - dense_1_acc_15: 0.2667 - dense_1_acc_16: 0.3000 - dense_1_acc_17: 0.2667 - dense_1_acc_18: 0.2667 - dense_1_acc_19: 0.3000 - dense_1_acc_20: 0.2500 - dense_1_acc_21: 0.2667 - dense_1_acc_22: 0.2333 - dense_1_acc_23: 0.2333 - dense_1_acc_24: 0.1667 - dense_1_acc_25: 0.4000 - dense_1_acc_26: 0.2333 - dense_1_acc_27: 0.3000 - dense_1_acc_28: 0.2833 - dense_1_acc_29: 0.0000e+00
# Epoch 15/100
# 60/60 [==============================] - 0s 2ms/step - loss: 75.6978 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.0667 - dense_1_acc_1: 0.2000 - dense_1_acc_2: 0.2833 - dense_1_acc_3: 0.2500 - dense_1_acc_4: 0.3167 - dense_1_acc_5: 0.2167 - dense_1_acc_6: 0.3000 - dense_1_acc_7: 0.3167 - dense_1_acc_8: 0.2667 - dense_1_acc_9: 0.2500 - dense_1_acc_10: 0.3167 - dense_1_acc_11: 0.2000 - dense_1_acc_12: 0.3500 - dense_1_acc_13: 0.3500 - dense_1_acc_14: 0.3000 - dense_1_acc_15: 0.2000 - dense_1_acc_16: 0.3333 - dense_1_acc_17: 0.2833 - dense_1_acc_18: 0.3000 - dense_1_acc_19: 0.3333 - dense_1_acc_20: 0.3500 - dense_1_acc_21: 0.2667 - dense_1_acc_22: 0.2500 - dense_1_acc_23: 0.2500 - dense_1_acc_24: 0.2167 - dense_1_acc_25: 0.3667 - dense_1_acc_26: 0.3667 - dense_1_acc_27: 0.4000 - dense_1_acc_28: 0.3500 - dense_1_acc_29: 0.0000e+00
# Epoch 16/100
# 60/60 [==============================] - 0s 2ms/step - loss: 71.8520 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.1000 - dense_1_acc_1: 0.2500 - dense_1_acc_2: 0.2833 - dense_1_acc_3: 0.2500 - dense_1_acc_4: 0.3500 - dense_1_acc_5: 0.3167 - dense_1_acc_6: 0.3167 - dense_1_acc_7: 0.3333 - dense_1_acc_8: 0.2833 - dense_1_acc_9: 0.3167 - dense_1_acc_10: 0.3167 - dense_1_acc_11: 0.3167 - dense_1_acc_12: 0.3667 - dense_1_acc_13: 0.4667 - dense_1_acc_14: 0.2833 - dense_1_acc_15: 0.2500 - dense_1_acc_16: 0.4000 - dense_1_acc_17: 0.3000 - dense_1_acc_18: 0.4000 - dense_1_acc_19: 0.3500 - dense_1_acc_20: 0.3500 - dense_1_acc_21: 0.3333 - dense_1_acc_22: 0.3167 - dense_1_acc_23: 0.3000 - dense_1_acc_24: 0.2667 - dense_1_acc_25: 0.5667 - dense_1_acc_26: 0.3833 - dense_1_acc_27: 0.4167 - dense_1_acc_28: 0.3833 - dense_1_acc_29: 0.0000e+00
# Epoch 17/100
# 60/60 [==============================] - 0s 2ms/step - loss: 68.8832 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.1000 - dense_1_acc_1: 0.2333 - dense_1_acc_2: 0.3167 - dense_1_acc_3: 0.2667 - dense_1_acc_4: 0.3667 - dense_1_acc_5: 0.3167 - dense_1_acc_6: 0.3167 - dense_1_acc_7: 0.4333 - dense_1_acc_8: 0.3333 - dense_1_acc_9: 0.3167 - dense_1_acc_10: 0.3667 - dense_1_acc_11: 0.4000 - dense_1_acc_12: 0.4167 - dense_1_acc_13: 0.4667 - dense_1_acc_14: 0.3667 - dense_1_acc_15: 0.3000 - dense_1_acc_16: 0.5167 - dense_1_acc_17: 0.3167 - dense_1_acc_18: 0.3833 - dense_1_acc_19: 0.4333 - dense_1_acc_20: 0.3333 - dense_1_acc_21: 0.2833 - dense_1_acc_22: 0.3667 - dense_1_acc_23: 0.3167 - dense_1_acc_24: 0.3000 - dense_1_acc_25: 0.5667 - dense_1_acc_26: 0.4333 - dense_1_acc_27: 0.3667 - dense_1_acc_28: 0.3667 - dense_1_acc_29: 0.0000e+00
# Epoch 18/100
# 60/60 [==============================] - 0s 2ms/step - loss: 65.7997 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.1000 - dense_1_acc_1: 0.2333 - dense_1_acc_2: 0.3500 - dense_1_acc_3: 0.2667 - dense_1_acc_4: 0.3667 - dense_1_acc_5: 0.3333 - dense_1_acc_6: 0.3167 - dense_1_acc_7: 0.4333 - dense_1_acc_8: 0.3333 - dense_1_acc_9: 0.3333 - dense_1_acc_10: 0.3667 - dense_1_acc_11: 0.4167 - dense_1_acc_12: 0.4500 - dense_1_acc_13: 0.4000 - dense_1_acc_14: 0.4000 - dense_1_acc_15: 0.3167 - dense_1_acc_16: 0.5000 - dense_1_acc_17: 0.3500 - dense_1_acc_18: 0.4167 - dense_1_acc_19: 0.4833 - dense_1_acc_20: 0.4333 - dense_1_acc_21: 0.3500 - dense_1_acc_22: 0.4167 - dense_1_acc_23: 0.3000 - dense_1_acc_24: 0.3500 - dense_1_acc_25: 0.5667 - dense_1_acc_26: 0.4667 - dense_1_acc_27: 0.4667 - dense_1_acc_28: 0.4500 - dense_1_acc_29: 0.0167
# Epoch 19/100
# 60/60 [==============================] - 0s 2ms/step - loss: 62.5658 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.0833 - dense_1_acc_1: 0.2333 - dense_1_acc_2: 0.3667 - dense_1_acc_3: 0.2667 - dense_1_acc_4: 0.3667 - dense_1_acc_5: 0.3167 - dense_1_acc_6: 0.3500 - dense_1_acc_7: 0.4167 - dense_1_acc_8: 0.4500 - dense_1_acc_9: 0.3833 - dense_1_acc_10: 0.4167 - dense_1_acc_11: 0.4667 - dense_1_acc_12: 0.5000 - dense_1_acc_13: 0.3833 - dense_1_acc_14: 0.4167 - dense_1_acc_15: 0.3167 - dense_1_acc_16: 0.5333 - dense_1_acc_17: 0.3833 - dense_1_acc_18: 0.4667 - dense_1_acc_19: 0.4333 - dense_1_acc_20: 0.5000 - dense_1_acc_21: 0.4500 - dense_1_acc_22: 0.4833 - dense_1_acc_23: 0.3500 - dense_1_acc_24: 0.3500 - dense_1_acc_25: 0.5167 - dense_1_acc_26: 0.4167 - dense_1_acc_27: 0.4500 - dense_1_acc_28: 0.4833 - dense_1_acc_29: 0.0167
# Epoch 20/100
# 60/60 [==============================] - 0s 2ms/step - loss: 59.6153 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.0667 - dense_1_acc_1: 0.2333 - dense_1_acc_2: 0.3833 - dense_1_acc_3: 0.2833 - dense_1_acc_4: 0.3833 - dense_1_acc_5: 0.3333 - dense_1_acc_6: 0.3333 - dense_1_acc_7: 0.4000 - dense_1_acc_8: 0.4000 - dense_1_acc_9: 0.3667 - dense_1_acc_10: 0.4500 - dense_1_acc_11: 0.4833 - dense_1_acc_12: 0.4833 - dense_1_acc_13: 0.3833 - dense_1_acc_14: 0.4000 - dense_1_acc_15: 0.3500 - dense_1_acc_16: 0.5333 - dense_1_acc_17: 0.4333 - dense_1_acc_18: 0.5000 - dense_1_acc_19: 0.4333 - dense_1_acc_20: 0.4833 - dense_1_acc_21: 0.4333 - dense_1_acc_22: 0.4667 - dense_1_acc_23: 0.4333 - dense_1_acc_24: 0.4000 - dense_1_acc_25: 0.5000 - dense_1_acc_26: 0.4000 - dense_1_acc_27: 0.5167 - dense_1_acc_28: 0.4500 - dense_1_acc_29: 0.0500
# Epoch 21/100
# 60/60 [==============================] - 0s 2ms/step - loss: 56.8483 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.0667 - dense_1_acc_1: 0.3000 - dense_1_acc_2: 0.3833 - dense_1_acc_3: 0.2833 - dense_1_acc_4: 0.4000 - dense_1_acc_5: 0.3833 - dense_1_acc_6: 0.4333 - dense_1_acc_7: 0.5000 - dense_1_acc_8: 0.4500 - dense_1_acc_9: 0.4833 - dense_1_acc_10: 0.4333 - dense_1_acc_11: 0.4833 - dense_1_acc_12: 0.5500 - dense_1_acc_13: 0.4833 - dense_1_acc_14: 0.4333 - dense_1_acc_15: 0.4167 - dense_1_acc_16: 0.5333 - dense_1_acc_17: 0.5333 - dense_1_acc_18: 0.5833 - dense_1_acc_19: 0.5833 - dense_1_acc_20: 0.5500 - dense_1_acc_21: 0.5667 - dense_1_acc_22: 0.6000 - dense_1_acc_23: 0.5333 - dense_1_acc_24: 0.4500 - dense_1_acc_25: 0.6500 - dense_1_acc_26: 0.5500 - dense_1_acc_27: 0.5667 - dense_1_acc_28: 0.6000 - dense_1_acc_29: 0.0167
# Epoch 22/100
# 60/60 [==============================] - 0s 2ms/step - loss: 54.1143 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.0667 - dense_1_acc_1: 0.3000 - dense_1_acc_2: 0.3833 - dense_1_acc_3: 0.2833 - dense_1_acc_4: 0.3667 - dense_1_acc_5: 0.4000 - dense_1_acc_6: 0.4500 - dense_1_acc_7: 0.4833 - dense_1_acc_8: 0.4833 - dense_1_acc_9: 0.5167 - dense_1_acc_10: 0.4167 - dense_1_acc_11: 0.5333 - dense_1_acc_12: 0.5667 - dense_1_acc_13: 0.4667 - dense_1_acc_14: 0.5333 - dense_1_acc_15: 0.4333 - dense_1_acc_16: 0.5667 - dense_1_acc_17: 0.4833 - dense_1_acc_18: 0.6167 - dense_1_acc_19: 0.5167 - dense_1_acc_20: 0.5667 - dense_1_acc_21: 0.5500 - dense_1_acc_22: 0.5500 - dense_1_acc_23: 0.5000 - dense_1_acc_24: 0.3667 - dense_1_acc_25: 0.7000 - dense_1_acc_26: 0.6167 - dense_1_acc_27: 0.5500 - dense_1_acc_28: 0.6333 - dense_1_acc_29: 0.0167
# Epoch 23/100
# 60/60 [==============================] - 0s 2ms/step - loss: 51.3568 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.0667 - dense_1_acc_1: 0.3000 - dense_1_acc_2: 0.3833 - dense_1_acc_3: 0.3167 - dense_1_acc_4: 0.3833 - dense_1_acc_5: 0.4333 - dense_1_acc_6: 0.5167 - dense_1_acc_7: 0.5000 - dense_1_acc_8: 0.5000 - dense_1_acc_9: 0.6167 - dense_1_acc_10: 0.5500 - dense_1_acc_11: 0.6333 - dense_1_acc_12: 0.6333 - dense_1_acc_13: 0.5667 - dense_1_acc_14: 0.6167 - dense_1_acc_15: 0.5000 - dense_1_acc_16: 0.6833 - dense_1_acc_17: 0.5667 - dense_1_acc_18: 0.7167 - dense_1_acc_19: 0.6500 - dense_1_acc_20: 0.6333 - dense_1_acc_21: 0.6000 - dense_1_acc_22: 0.6167 - dense_1_acc_23: 0.5667 - dense_1_acc_24: 0.4833 - dense_1_acc_25: 0.6667 - dense_1_acc_26: 0.6000 - dense_1_acc_27: 0.6500 - dense_1_acc_28: 0.6667 - dense_1_acc_29: 0.0167
# Epoch 24/100
# 60/60 [==============================] - 0s 2ms/step - loss: 48.9300 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.0667 - dense_1_acc_1: 0.3000 - dense_1_acc_2: 0.4000 - dense_1_acc_3: 0.3167 - dense_1_acc_4: 0.3833 - dense_1_acc_5: 0.4500 - dense_1_acc_6: 0.5167 - dense_1_acc_7: 0.5500 - dense_1_acc_8: 0.5833 - dense_1_acc_9: 0.6833 - dense_1_acc_10: 0.6333 - dense_1_acc_11: 0.6333 - dense_1_acc_12: 0.7333 - dense_1_acc_13: 0.6000 - dense_1_acc_14: 0.7167 - dense_1_acc_15: 0.5000 - dense_1_acc_16: 0.7167 - dense_1_acc_17: 0.6167 - dense_1_acc_18: 0.7167 - dense_1_acc_19: 0.7167 - dense_1_acc_20: 0.6333 - dense_1_acc_21: 0.6500 - dense_1_acc_22: 0.6333 - dense_1_acc_23: 0.6500 - dense_1_acc_24: 0.5167 - dense_1_acc_25: 0.7167 - dense_1_acc_26: 0.6333 - dense_1_acc_27: 0.6667 - dense_1_acc_28: 0.7500 - dense_1_acc_29: 0.0167
# Epoch 25/100
# 60/60 [==============================] - 0s 2ms/step - loss: 46.4455 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.0667 - dense_1_acc_1: 0.3000 - dense_1_acc_2: 0.4000 - dense_1_acc_3: 0.3333 - dense_1_acc_4: 0.4167 - dense_1_acc_5: 0.5167 - dense_1_acc_6: 0.6167 - dense_1_acc_7: 0.5667 - dense_1_acc_8: 0.5667 - dense_1_acc_9: 0.6333 - dense_1_acc_10: 0.7000 - dense_1_acc_11: 0.6500 - dense_1_acc_12: 0.8167 - dense_1_acc_13: 0.8167 - dense_1_acc_14: 0.6833 - dense_1_acc_15: 0.6500 - dense_1_acc_16: 0.7667 - dense_1_acc_17: 0.6333 - dense_1_acc_18: 0.6833 - dense_1_acc_19: 0.7000 - dense_1_acc_20: 0.7167 - dense_1_acc_21: 0.7000 - dense_1_acc_22: 0.6167 - dense_1_acc_23: 0.6500 - dense_1_acc_24: 0.6500 - dense_1_acc_25: 0.7833 - dense_1_acc_26: 0.7333 - dense_1_acc_27: 0.7833 - dense_1_acc_28: 0.7833 - dense_1_acc_29: 0.0333
# Epoch 26/100
# 60/60 [==============================] - 0s 2ms/step - loss: 44.0232 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.0667 - dense_1_acc_1: 0.3167 - dense_1_acc_2: 0.4000 - dense_1_acc_3: 0.3333 - dense_1_acc_4: 0.4500 - dense_1_acc_5: 0.5167 - dense_1_acc_6: 0.6000 - dense_1_acc_7: 0.6333 - dense_1_acc_8: 0.6667 - dense_1_acc_9: 0.7000 - dense_1_acc_10: 0.7000 - dense_1_acc_11: 0.6833 - dense_1_acc_12: 0.8667 - dense_1_acc_13: 0.7833 - dense_1_acc_14: 0.7000 - dense_1_acc_15: 0.7167 - dense_1_acc_16: 0.7333 - dense_1_acc_17: 0.7000 - dense_1_acc_18: 0.7333 - dense_1_acc_19: 0.8000 - dense_1_acc_20: 0.7333 - dense_1_acc_21: 0.7333 - dense_1_acc_22: 0.7000 - dense_1_acc_23: 0.6833 - dense_1_acc_24: 0.7000 - dense_1_acc_25: 0.8167 - dense_1_acc_26: 0.7667 - dense_1_acc_27: 0.8000 - dense_1_acc_28: 0.8000 - dense_1_acc_29: 0.0333
# Epoch 27/100
# 60/60 [==============================] - 0s 2ms/step - loss: 41.8082 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.0667 - dense_1_acc_1: 0.3333 - dense_1_acc_2: 0.4000 - dense_1_acc_3: 0.3667 - dense_1_acc_4: 0.5000 - dense_1_acc_5: 0.5333 - dense_1_acc_6: 0.6500 - dense_1_acc_7: 0.6833 - dense_1_acc_8: 0.7667 - dense_1_acc_9: 0.7667 - dense_1_acc_10: 0.7500 - dense_1_acc_11: 0.8667 - dense_1_acc_12: 0.8667 - dense_1_acc_13: 0.8500 - dense_1_acc_14: 0.7833 - dense_1_acc_15: 0.8000 - dense_1_acc_16: 0.8167 - dense_1_acc_17: 0.8167 - dense_1_acc_18: 0.8500 - dense_1_acc_19: 0.8333 - dense_1_acc_20: 0.7500 - dense_1_acc_21: 0.9000 - dense_1_acc_22: 0.8500 - dense_1_acc_23: 0.7667 - dense_1_acc_24: 0.7667 - dense_1_acc_25: 0.8167 - dense_1_acc_26: 0.8000 - dense_1_acc_27: 0.8000 - dense_1_acc_28: 0.8167 - dense_1_acc_29: 0.0500
# Epoch 28/100
# 60/60 [==============================] - 0s 2ms/step - loss: 39.6400 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.0667 - dense_1_acc_1: 0.4000 - dense_1_acc_2: 0.4000 - dense_1_acc_3: 0.4167 - dense_1_acc_4: 0.4833 - dense_1_acc_5: 0.5833 - dense_1_acc_6: 0.7667 - dense_1_acc_7: 0.7000 - dense_1_acc_8: 0.7667 - dense_1_acc_9: 0.7667 - dense_1_acc_10: 0.8000 - dense_1_acc_11: 0.9000 - dense_1_acc_12: 0.8833 - dense_1_acc_13: 0.8167 - dense_1_acc_14: 0.8167 - dense_1_acc_15: 0.8667 - dense_1_acc_16: 0.8833 - dense_1_acc_17: 0.9833 - dense_1_acc_18: 0.9167 - dense_1_acc_19: 0.8667 - dense_1_acc_20: 0.9000 - dense_1_acc_21: 0.9500 - dense_1_acc_22: 0.8833 - dense_1_acc_23: 0.8833 - dense_1_acc_24: 0.9167 - dense_1_acc_25: 0.9500 - dense_1_acc_26: 0.8833 - dense_1_acc_27: 0.8833 - dense_1_acc_28: 0.8167 - dense_1_acc_29: 0.0167
# Epoch 29/100
# 60/60 [==============================] - 0s 2ms/step - loss: 37.5828 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.0667 - dense_1_acc_1: 0.4000 - dense_1_acc_2: 0.4000 - dense_1_acc_3: 0.4167 - dense_1_acc_4: 0.5667 - dense_1_acc_5: 0.6167 - dense_1_acc_6: 0.8167 - dense_1_acc_7: 0.7333 - dense_1_acc_8: 0.7833 - dense_1_acc_9: 0.7833 - dense_1_acc_10: 0.8333 - dense_1_acc_11: 0.9000 - dense_1_acc_12: 0.9167 - dense_1_acc_13: 0.8833 - dense_1_acc_14: 0.8833 - dense_1_acc_15: 0.8500 - dense_1_acc_16: 0.8833 - dense_1_acc_17: 0.9167 - dense_1_acc_18: 0.9167 - dense_1_acc_19: 0.8667 - dense_1_acc_20: 0.8500 - dense_1_acc_21: 0.9333 - dense_1_acc_22: 0.8833 - dense_1_acc_23: 0.9500 - dense_1_acc_24: 0.8833 - dense_1_acc_25: 0.9500 - dense_1_acc_26: 0.8833 - dense_1_acc_27: 0.8667 - dense_1_acc_28: 0.8500 - dense_1_acc_29: 0.0167
# Epoch 30/100
# 60/60 [==============================] - 0s 2ms/step - loss: 35.6831 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.0667 - dense_1_acc_1: 0.4000 - dense_1_acc_2: 0.4000 - dense_1_acc_3: 0.4333 - dense_1_acc_4: 0.5833 - dense_1_acc_5: 0.6333 - dense_1_acc_6: 0.7833 - dense_1_acc_7: 0.7667 - dense_1_acc_8: 0.8167 - dense_1_acc_9: 0.8333 - dense_1_acc_10: 0.8167 - dense_1_acc_11: 0.9333 - dense_1_acc_12: 0.9000 - dense_1_acc_13: 0.9000 - dense_1_acc_14: 0.8500 - dense_1_acc_15: 0.8833 - dense_1_acc_16: 0.9000 - dense_1_acc_17: 0.9333 - dense_1_acc_18: 0.9167 - dense_1_acc_19: 0.8667 - dense_1_acc_20: 0.8833 - dense_1_acc_21: 0.9000 - dense_1_acc_22: 0.9000 - dense_1_acc_23: 0.8833 - dense_1_acc_24: 0.8667 - dense_1_acc_25: 0.9500 - dense_1_acc_26: 0.8833 - dense_1_acc_27: 0.9000 - dense_1_acc_28: 0.8167 - dense_1_acc_29: 0.0167
# Epoch 31/100
# 60/60 [==============================] - 0s 2ms/step - loss: 33.8194 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.0667 - dense_1_acc_1: 0.4000 - dense_1_acc_2: 0.4500 - dense_1_acc_3: 0.4333 - dense_1_acc_4: 0.6167 - dense_1_acc_5: 0.6833 - dense_1_acc_6: 0.8667 - dense_1_acc_7: 0.7833 - dense_1_acc_8: 0.8667 - dense_1_acc_9: 0.8500 - dense_1_acc_10: 0.8500 - dense_1_acc_11: 0.9333 - dense_1_acc_12: 0.9500 - dense_1_acc_13: 0.9500 - dense_1_acc_14: 0.9667 - dense_1_acc_15: 0.9167 - dense_1_acc_16: 0.9000 - dense_1_acc_17: 1.0000 - dense_1_acc_18: 0.9333 - dense_1_acc_19: 0.9167 - dense_1_acc_20: 0.9500 - dense_1_acc_21: 0.9667 - dense_1_acc_22: 0.9333 - dense_1_acc_23: 0.9667 - dense_1_acc_24: 0.9500 - dense_1_acc_25: 0.9833 - dense_1_acc_26: 0.9167 - dense_1_acc_27: 0.9167 - dense_1_acc_28: 0.8667 - dense_1_acc_29: 0.0167
# Epoch 32/100
# 60/60 [==============================] - 0s 2ms/step - loss: 32.0633 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.0667 - dense_1_acc_1: 0.4000 - dense_1_acc_2: 0.4500 - dense_1_acc_3: 0.4333 - dense_1_acc_4: 0.6167 - dense_1_acc_5: 0.7333 - dense_1_acc_6: 0.9167 - dense_1_acc_7: 0.8667 - dense_1_acc_8: 0.9000 - dense_1_acc_9: 0.8667 - dense_1_acc_10: 0.8833 - dense_1_acc_11: 0.9667 - dense_1_acc_12: 0.9500 - dense_1_acc_13: 0.9500 - dense_1_acc_14: 0.9500 - dense_1_acc_15: 0.9500 - dense_1_acc_16: 0.9167 - dense_1_acc_17: 1.0000 - dense_1_acc_18: 0.9333 - dense_1_acc_19: 0.9333 - dense_1_acc_20: 0.9333 - dense_1_acc_21: 0.9667 - dense_1_acc_22: 0.9333 - dense_1_acc_23: 0.9667 - dense_1_acc_24: 0.9333 - dense_1_acc_25: 0.9833 - dense_1_acc_26: 0.9500 - dense_1_acc_27: 0.9500 - dense_1_acc_28: 0.9333 - dense_1_acc_29: 0.0167
# Epoch 33/100
# 60/60 [==============================] - 0s 2ms/step - loss: 30.2562 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.0667 - dense_1_acc_1: 0.4000 - dense_1_acc_2: 0.5000 - dense_1_acc_3: 0.4833 - dense_1_acc_4: 0.6167 - dense_1_acc_5: 0.7500 - dense_1_acc_6: 0.9333 - dense_1_acc_7: 0.8667 - dense_1_acc_8: 0.8833 - dense_1_acc_9: 0.9000 - dense_1_acc_10: 0.8667 - dense_1_acc_11: 0.9500 - dense_1_acc_12: 0.9667 - dense_1_acc_13: 0.9667 - dense_1_acc_14: 0.9833 - dense_1_acc_15: 0.9167 - dense_1_acc_16: 0.9333 - dense_1_acc_17: 1.0000 - dense_1_acc_18: 0.9500 - dense_1_acc_19: 0.9500 - dense_1_acc_20: 0.9500 - dense_1_acc_21: 0.9667 - dense_1_acc_22: 0.9667 - dense_1_acc_23: 0.9667 - dense_1_acc_24: 0.9500 - dense_1_acc_25: 0.9833 - dense_1_acc_26: 0.9500 - dense_1_acc_27: 0.9333 - dense_1_acc_28: 0.8833 - dense_1_acc_29: 0.0167
# Epoch 34/100
# 60/60 [==============================] - 0s 2ms/step - loss: 28.7538 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.0667 - dense_1_acc_1: 0.4000 - dense_1_acc_2: 0.5333 - dense_1_acc_3: 0.5500 - dense_1_acc_4: 0.6333 - dense_1_acc_5: 0.8000 - dense_1_acc_6: 0.9333 - dense_1_acc_7: 0.9000 - dense_1_acc_8: 0.8667 - dense_1_acc_9: 0.9333 - dense_1_acc_10: 0.8833 - dense_1_acc_11: 0.9667 - dense_1_acc_12: 0.9833 - dense_1_acc_13: 0.9667 - dense_1_acc_14: 0.9833 - dense_1_acc_15: 0.9333 - dense_1_acc_16: 0.9500 - dense_1_acc_17: 0.9833 - dense_1_acc_18: 0.9500 - dense_1_acc_19: 0.9333 - dense_1_acc_20: 1.0000 - dense_1_acc_21: 0.9833 - dense_1_acc_22: 0.9667 - dense_1_acc_23: 0.9500 - dense_1_acc_24: 0.9500 - dense_1_acc_25: 0.9833 - dense_1_acc_26: 0.9333 - dense_1_acc_27: 0.9500 - dense_1_acc_28: 0.9000 - dense_1_acc_29: 0.0167
# Epoch 35/100
# 60/60 [==============================] - 0s 2ms/step - loss: 27.2150 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.0667 - dense_1_acc_1: 0.4000 - dense_1_acc_2: 0.5500 - dense_1_acc_3: 0.6000 - dense_1_acc_4: 0.6833 - dense_1_acc_5: 0.8667 - dense_1_acc_6: 0.9333 - dense_1_acc_7: 0.9333 - dense_1_acc_8: 0.9000 - dense_1_acc_9: 0.9333 - dense_1_acc_10: 0.9167 - dense_1_acc_11: 0.9667 - dense_1_acc_12: 1.0000 - dense_1_acc_13: 0.9833 - dense_1_acc_14: 0.9833 - dense_1_acc_15: 0.9667 - dense_1_acc_16: 1.0000 - dense_1_acc_17: 1.0000 - dense_1_acc_18: 0.9667 - dense_1_acc_19: 0.9833 - dense_1_acc_20: 1.0000 - dense_1_acc_21: 1.0000 - dense_1_acc_22: 0.9833 - dense_1_acc_23: 0.9667 - dense_1_acc_24: 0.9667 - dense_1_acc_25: 0.9833 - dense_1_acc_26: 0.9500 - dense_1_acc_27: 0.9500 - dense_1_acc_28: 0.9333 - dense_1_acc_29: 0.0167
# Epoch 36/100
# 60/60 [==============================] - 0s 2ms/step - loss: 25.7769 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.0667 - dense_1_acc_1: 0.4000 - dense_1_acc_2: 0.5500 - dense_1_acc_3: 0.6333 - dense_1_acc_4: 0.6833 - dense_1_acc_5: 0.8833 - dense_1_acc_6: 0.9333 - dense_1_acc_7: 0.9500 - dense_1_acc_8: 0.9167 - dense_1_acc_9: 0.9500 - dense_1_acc_10: 0.9833 - dense_1_acc_11: 0.9833 - dense_1_acc_12: 0.9667 - dense_1_acc_13: 1.0000 - dense_1_acc_14: 1.0000 - dense_1_acc_15: 0.9833 - dense_1_acc_16: 1.0000 - dense_1_acc_17: 1.0000 - dense_1_acc_18: 0.9833 - dense_1_acc_19: 0.9667 - dense_1_acc_20: 0.9833 - dense_1_acc_21: 1.0000 - dense_1_acc_22: 0.9833 - dense_1_acc_23: 1.0000 - dense_1_acc_24: 0.9833 - dense_1_acc_25: 0.9833 - dense_1_acc_26: 1.0000 - dense_1_acc_27: 0.9833 - dense_1_acc_28: 0.9667 - dense_1_acc_29: 0.0167
# Epoch 37/100
# 60/60 [==============================] - 0s 2ms/step - loss: 24.3902 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.0667 - dense_1_acc_1: 0.4167 - dense_1_acc_2: 0.5500 - dense_1_acc_3: 0.6500 - dense_1_acc_4: 0.7167 - dense_1_acc_5: 0.8833 - dense_1_acc_6: 0.9833 - dense_1_acc_7: 0.9667 - dense_1_acc_8: 0.9333 - dense_1_acc_9: 0.9833 - dense_1_acc_10: 0.9833 - dense_1_acc_11: 0.9833 - dense_1_acc_12: 0.9833 - dense_1_acc_13: 0.9833 - dense_1_acc_14: 1.0000 - dense_1_acc_15: 1.0000 - dense_1_acc_16: 1.0000 - dense_1_acc_17: 1.0000 - dense_1_acc_18: 0.9833 - dense_1_acc_19: 1.0000 - dense_1_acc_20: 1.0000 - dense_1_acc_21: 1.0000 - dense_1_acc_22: 0.9833 - dense_1_acc_23: 1.0000 - dense_1_acc_24: 0.9667 - dense_1_acc_25: 0.9833 - dense_1_acc_26: 1.0000 - dense_1_acc_27: 0.9667 - dense_1_acc_28: 0.9500 - dense_1_acc_29: 0.0167
# Epoch 38/100
# 60/60 [==============================] - 0s 2ms/step - loss: 23.1411 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.0667 - dense_1_acc_1: 0.4167 - dense_1_acc_2: 0.5500 - dense_1_acc_3: 0.6500 - dense_1_acc_4: 0.8000 - dense_1_acc_5: 0.9000 - dense_1_acc_6: 0.9667 - dense_1_acc_7: 0.9667 - dense_1_acc_8: 0.9500 - dense_1_acc_9: 0.9833 - dense_1_acc_10: 1.0000 - dense_1_acc_11: 1.0000 - dense_1_acc_12: 1.0000 - dense_1_acc_13: 0.9833 - dense_1_acc_14: 1.0000 - dense_1_acc_15: 1.0000 - dense_1_acc_16: 1.0000 - dense_1_acc_17: 1.0000 - dense_1_acc_18: 1.0000 - dense_1_acc_19: 0.9667 - dense_1_acc_20: 1.0000 - dense_1_acc_21: 1.0000 - dense_1_acc_22: 1.0000 - dense_1_acc_23: 1.0000 - dense_1_acc_24: 0.9667 - dense_1_acc_25: 0.9833 - dense_1_acc_26: 1.0000 - dense_1_acc_27: 0.9500 - dense_1_acc_28: 0.9167 - dense_1_acc_29: 0.0167
# Epoch 39/100
# 60/60 [==============================] - 0s 2ms/step - loss: 21.9395 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.0667 - dense_1_acc_1: 0.4167 - dense_1_acc_2: 0.5667 - dense_1_acc_3: 0.7167 - dense_1_acc_4: 0.8500 - dense_1_acc_5: 0.9167 - dense_1_acc_6: 0.9667 - dense_1_acc_7: 0.9833 - dense_1_acc_8: 0.9667 - dense_1_acc_9: 1.0000 - dense_1_acc_10: 0.9833 - dense_1_acc_11: 1.0000 - dense_1_acc_12: 1.0000 - dense_1_acc_13: 1.0000 - dense_1_acc_14: 1.0000 - dense_1_acc_15: 1.0000 - dense_1_acc_16: 1.0000 - dense_1_acc_17: 1.0000 - dense_1_acc_18: 1.0000 - dense_1_acc_19: 1.0000 - dense_1_acc_20: 1.0000 - dense_1_acc_21: 1.0000 - dense_1_acc_22: 1.0000 - dense_1_acc_23: 1.0000 - dense_1_acc_24: 1.0000 - dense_1_acc_25: 0.9833 - dense_1_acc_26: 1.0000 - dense_1_acc_27: 0.9833 - dense_1_acc_28: 0.9667 - dense_1_acc_29: 0.0167
# Epoch 40/100
# 60/60 [==============================] - 0s 2ms/step - loss: 20.7733 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.0667 - dense_1_acc_1: 0.4333 - dense_1_acc_2: 0.5833 - dense_1_acc_3: 0.7167 - dense_1_acc_4: 0.8667 - dense_1_acc_5: 0.9333 - dense_1_acc_6: 0.9667 - dense_1_acc_7: 0.9833 - dense_1_acc_8: 0.9667 - dense_1_acc_9: 1.0000 - dense_1_acc_10: 1.0000 - dense_1_acc_11: 0.9833 - dense_1_acc_12: 1.0000 - dense_1_acc_13: 1.0000 - dense_1_acc_14: 1.0000 - dense_1_acc_15: 1.0000 - dense_1_acc_16: 1.0000 - dense_1_acc_17: 1.0000 - dense_1_acc_18: 1.0000 - dense_1_acc_19: 1.0000 - dense_1_acc_20: 1.0000 - dense_1_acc_21: 1.0000 - dense_1_acc_22: 1.0000 - dense_1_acc_23: 1.0000 - dense_1_acc_24: 1.0000 - dense_1_acc_25: 0.9833 - dense_1_acc_26: 1.0000 - dense_1_acc_27: 0.9833 - dense_1_acc_28: 0.9667 - dense_1_acc_29: 0.0167
# Epoch 41/100
# 60/60 [==============================] - 0s 2ms/step - loss: 19.7777 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.0667 - dense_1_acc_1: 0.4500 - dense_1_acc_2: 0.6333 - dense_1_acc_3: 0.7333 - dense_1_acc_4: 0.8667 - dense_1_acc_5: 0.9500 - dense_1_acc_6: 0.9833 - dense_1_acc_7: 0.9833 - dense_1_acc_8: 0.9667 - dense_1_acc_9: 1.0000 - dense_1_acc_10: 1.0000 - dense_1_acc_11: 1.0000 - dense_1_acc_12: 1.0000 - dense_1_acc_13: 1.0000 - dense_1_acc_14: 1.0000 - dense_1_acc_15: 1.0000 - dense_1_acc_16: 1.0000 - dense_1_acc_17: 1.0000 - dense_1_acc_18: 1.0000 - dense_1_acc_19: 1.0000 - dense_1_acc_20: 1.0000 - dense_1_acc_21: 1.0000 - dense_1_acc_22: 1.0000 - dense_1_acc_23: 1.0000 - dense_1_acc_24: 1.0000 - dense_1_acc_25: 0.9833 - dense_1_acc_26: 1.0000 - dense_1_acc_27: 0.9833 - dense_1_acc_28: 0.9833 - dense_1_acc_29: 0.0167
# Epoch 42/100
# 60/60 [==============================] - 0s 2ms/step - loss: 18.7652 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.0667 - dense_1_acc_1: 0.4500 - dense_1_acc_2: 0.6667 - dense_1_acc_3: 0.7333 - dense_1_acc_4: 0.8833 - dense_1_acc_5: 0.9500 - dense_1_acc_6: 0.9833 - dense_1_acc_7: 0.9833 - dense_1_acc_8: 0.9667 - dense_1_acc_9: 1.0000 - dense_1_acc_10: 1.0000 - dense_1_acc_11: 1.0000 - dense_1_acc_12: 1.0000 - dense_1_acc_13: 1.0000 - dense_1_acc_14: 1.0000 - dense_1_acc_15: 1.0000 - dense_1_acc_16: 1.0000 - dense_1_acc_17: 1.0000 - dense_1_acc_18: 1.0000 - dense_1_acc_19: 1.0000 - dense_1_acc_20: 1.0000 - dense_1_acc_21: 1.0000 - dense_1_acc_22: 1.0000 - dense_1_acc_23: 1.0000 - dense_1_acc_24: 1.0000 - dense_1_acc_25: 0.9833 - dense_1_acc_26: 1.0000 - dense_1_acc_27: 0.9833 - dense_1_acc_28: 0.9667 - dense_1_acc_29: 0.0167
# Epoch 43/100
# 60/60 [==============================] - 0s 2ms/step - loss: 17.9071 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.0667 - dense_1_acc_1: 0.4500 - dense_1_acc_2: 0.7000 - dense_1_acc_3: 0.8000 - dense_1_acc_4: 0.9333 - dense_1_acc_5: 0.9500 - dense_1_acc_6: 0.9833 - dense_1_acc_7: 0.9833 - dense_1_acc_8: 0.9667 - dense_1_acc_9: 1.0000 - dense_1_acc_10: 1.0000 - dense_1_acc_11: 1.0000 - dense_1_acc_12: 1.0000 - dense_1_acc_13: 1.0000 - dense_1_acc_14: 1.0000 - dense_1_acc_15: 1.0000 - dense_1_acc_16: 1.0000 - dense_1_acc_17: 1.0000 - dense_1_acc_18: 1.0000 - dense_1_acc_19: 1.0000 - dense_1_acc_20: 1.0000 - dense_1_acc_21: 1.0000 - dense_1_acc_22: 1.0000 - dense_1_acc_23: 1.0000 - dense_1_acc_24: 1.0000 - dense_1_acc_25: 1.0000 - dense_1_acc_26: 1.0000 - dense_1_acc_27: 0.9833 - dense_1_acc_28: 0.9667 - dense_1_acc_29: 0.0167
# Epoch 44/100
# 60/60 [==============================] - 0s 3ms/step - loss: 17.0790 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.0667 - dense_1_acc_1: 0.4333 - dense_1_acc_2: 0.7167 - dense_1_acc_3: 0.8833 - dense_1_acc_4: 0.9500 - dense_1_acc_5: 0.9500 - dense_1_acc_6: 0.9833 - dense_1_acc_7: 0.9833 - dense_1_acc_8: 0.9833 - dense_1_acc_9: 1.0000 - dense_1_acc_10: 1.0000 - dense_1_acc_11: 1.0000 - dense_1_acc_12: 1.0000 - dense_1_acc_13: 1.0000 - dense_1_acc_14: 1.0000 - dense_1_acc_15: 1.0000 - dense_1_acc_16: 1.0000 - dense_1_acc_17: 1.0000 - dense_1_acc_18: 1.0000 - dense_1_acc_19: 1.0000 - dense_1_acc_20: 1.0000 - dense_1_acc_21: 1.0000 - dense_1_acc_22: 1.0000 - dense_1_acc_23: 1.0000 - dense_1_acc_24: 1.0000 - dense_1_acc_25: 1.0000 - dense_1_acc_26: 1.0000 - dense_1_acc_27: 0.9833 - dense_1_acc_28: 0.9833 - dense_1_acc_29: 0.0167
# Epoch 45/100
# 60/60 [==============================] - 0s 2ms/step - loss: 16.2824 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.0667 - dense_1_acc_1: 0.4500 - dense_1_acc_2: 0.7333 - dense_1_acc_3: 0.9000 - dense_1_acc_4: 0.9500 - dense_1_acc_5: 0.9500 - dense_1_acc_6: 0.9833 - dense_1_acc_7: 0.9833 - dense_1_acc_8: 0.9833 - dense_1_acc_9: 1.0000 - dense_1_acc_10: 1.0000 - dense_1_acc_11: 1.0000 - dense_1_acc_12: 1.0000 - dense_1_acc_13: 1.0000 - dense_1_acc_14: 1.0000 - dense_1_acc_15: 1.0000 - dense_1_acc_16: 1.0000 - dense_1_acc_17: 1.0000 - dense_1_acc_18: 1.0000 - dense_1_acc_19: 1.0000 - dense_1_acc_20: 1.0000 - dense_1_acc_21: 1.0000 - dense_1_acc_22: 1.0000 - dense_1_acc_23: 1.0000 - dense_1_acc_24: 1.0000 - dense_1_acc_25: 1.0000 - dense_1_acc_26: 1.0000 - dense_1_acc_27: 1.0000 - dense_1_acc_28: 0.9833 - dense_1_acc_29: 0.0167
# Epoch 46/100
# 60/60 [==============================] - 0s 2ms/step - loss: 15.5826 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.0667 - dense_1_acc_1: 0.4500 - dense_1_acc_2: 0.7333 - dense_1_acc_3: 0.9000 - dense_1_acc_4: 0.9833 - dense_1_acc_5: 0.9667 - dense_1_acc_6: 0.9833 - dense_1_acc_7: 0.9833 - dense_1_acc_8: 0.9833 - dense_1_acc_9: 1.0000 - dense_1_acc_10: 1.0000 - dense_1_acc_11: 1.0000 - dense_1_acc_12: 1.0000 - dense_1_acc_13: 1.0000 - dense_1_acc_14: 1.0000 - dense_1_acc_15: 1.0000 - dense_1_acc_16: 1.0000 - dense_1_acc_17: 1.0000 - dense_1_acc_18: 1.0000 - dense_1_acc_19: 1.0000 - dense_1_acc_20: 1.0000 - dense_1_acc_21: 1.0000 - dense_1_acc_22: 1.0000 - dense_1_acc_23: 1.0000 - dense_1_acc_24: 1.0000 - dense_1_acc_25: 1.0000 - dense_1_acc_26: 1.0000 - dense_1_acc_27: 1.0000 - dense_1_acc_28: 0.9833 - dense_1_acc_29: 0.0167
# Epoch 47/100
# 60/60 [==============================] - 0s 6ms/step - loss: 14.9541 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.0667 - dense_1_acc_1: 0.4500 - dense_1_acc_2: 0.7500 - dense_1_acc_3: 0.9000 - dense_1_acc_4: 0.9833 - dense_1_acc_5: 0.9667 - dense_1_acc_6: 0.9833 - dense_1_acc_7: 0.9833 - dense_1_acc_8: 0.9833 - dense_1_acc_9: 1.0000 - dense_1_acc_10: 1.0000 - dense_1_acc_11: 1.0000 - dense_1_acc_12: 1.0000 - dense_1_acc_13: 1.0000 - dense_1_acc_14: 1.0000 - dense_1_acc_15: 1.0000 - dense_1_acc_16: 1.0000 - dense_1_acc_17: 1.0000 - dense_1_acc_18: 1.0000 - dense_1_acc_19: 1.0000 - dense_1_acc_20: 1.0000 - dense_1_acc_21: 1.0000 - dense_1_acc_22: 1.0000 - dense_1_acc_23: 1.0000 - dense_1_acc_24: 1.0000 - dense_1_acc_25: 1.0000 - dense_1_acc_26: 1.0000 - dense_1_acc_27: 1.0000 - dense_1_acc_28: 0.9833 - dense_1_acc_29: 0.0167
# Epoch 48/100
# 60/60 [==============================] - 0s 2ms/step - loss: 14.3357 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.0667 - dense_1_acc_1: 0.4500 - dense_1_acc_2: 0.7500 - dense_1_acc_3: 0.9000 - dense_1_acc_4: 0.9833 - dense_1_acc_5: 0.9667 - dense_1_acc_6: 0.9833 - dense_1_acc_7: 0.9833 - dense_1_acc_8: 1.0000 - dense_1_acc_9: 1.0000 - dense_1_acc_10: 1.0000 - dense_1_acc_11: 1.0000 - dense_1_acc_12: 1.0000 - dense_1_acc_13: 1.0000 - dense_1_acc_14: 1.0000 - dense_1_acc_15: 1.0000 - dense_1_acc_16: 1.0000 - dense_1_acc_17: 1.0000 - dense_1_acc_18: 1.0000 - dense_1_acc_19: 1.0000 - dense_1_acc_20: 1.0000 - dense_1_acc_21: 1.0000 - dense_1_acc_22: 1.0000 - dense_1_acc_23: 1.0000 - dense_1_acc_24: 1.0000 - dense_1_acc_25: 1.0000 - dense_1_acc_26: 1.0000 - dense_1_acc_27: 1.0000 - dense_1_acc_28: 0.9833 - dense_1_acc_29: 0.0167
# Epoch 49/100
# 60/60 [==============================] - 0s 2ms/step - loss: 13.8033 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.0667 - dense_1_acc_1: 0.4500 - dense_1_acc_2: 0.7667 - dense_1_acc_3: 0.9167 - dense_1_acc_4: 0.9833 - dense_1_acc_5: 0.9667 - dense_1_acc_6: 0.9833 - dense_1_acc_7: 0.9833 - dense_1_acc_8: 1.0000 - dense_1_acc_9: 1.0000 - dense_1_acc_10: 1.0000 - dense_1_acc_11: 1.0000 - dense_1_acc_12: 1.0000 - dense_1_acc_13: 1.0000 - dense_1_acc_14: 1.0000 - dense_1_acc_15: 1.0000 - dense_1_acc_16: 1.0000 - dense_1_acc_17: 1.0000 - dense_1_acc_18: 1.0000 - dense_1_acc_19: 1.0000 - dense_1_acc_20: 1.0000 - dense_1_acc_21: 1.0000 - dense_1_acc_22: 1.0000 - dense_1_acc_23: 1.0000 - dense_1_acc_24: 1.0000 - dense_1_acc_25: 1.0000 - dense_1_acc_26: 1.0000 - dense_1_acc_27: 1.0000 - dense_1_acc_28: 1.0000 - dense_1_acc_29: 0.0167
# Epoch 50/100
# 60/60 [==============================] - 0s 2ms/step - loss: 13.2920 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.0667 - dense_1_acc_1: 0.4667 - dense_1_acc_2: 0.8000 - dense_1_acc_3: 0.9167 - dense_1_acc_4: 0.9833 - dense_1_acc_5: 0.9667 - dense_1_acc_6: 1.0000 - dense_1_acc_7: 0.9833 - dense_1_acc_8: 1.0000 - dense_1_acc_9: 1.0000 - dense_1_acc_10: 1.0000 - dense_1_acc_11: 1.0000 - dense_1_acc_12: 1.0000 - dense_1_acc_13: 1.0000 - dense_1_acc_14: 1.0000 - dense_1_acc_15: 1.0000 - dense_1_acc_16: 1.0000 - dense_1_acc_17: 1.0000 - dense_1_acc_18: 1.0000 - dense_1_acc_19: 1.0000 - dense_1_acc_20: 1.0000 - dense_1_acc_21: 1.0000 - dense_1_acc_22: 1.0000 - dense_1_acc_23: 1.0000 - dense_1_acc_24: 1.0000 - dense_1_acc_25: 1.0000 - dense_1_acc_26: 1.0000 - dense_1_acc_27: 1.0000 - dense_1_acc_28: 1.0000 - dense_1_acc_29: 0.0167
# Epoch 51/100
# 60/60 [==============================] - 0s 2ms/step - loss: 12.8195 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.0667 - dense_1_acc_1: 0.4833 - dense_1_acc_2: 0.8000 - dense_1_acc_3: 0.9167 - dense_1_acc_4: 0.9833 - dense_1_acc_5: 0.9667 - dense_1_acc_6: 1.0000 - dense_1_acc_7: 0.9833 - dense_1_acc_8: 1.0000 - dense_1_acc_9: 1.0000 - dense_1_acc_10: 1.0000 - dense_1_acc_11: 1.0000 - dense_1_acc_12: 1.0000 - dense_1_acc_13: 1.0000 - dense_1_acc_14: 1.0000 - dense_1_acc_15: 1.0000 - dense_1_acc_16: 1.0000 - dense_1_acc_17: 1.0000 - dense_1_acc_18: 1.0000 - dense_1_acc_19: 1.0000 - dense_1_acc_20: 1.0000 - dense_1_acc_21: 1.0000 - dense_1_acc_22: 1.0000 - dense_1_acc_23: 1.0000 - dense_1_acc_24: 1.0000 - dense_1_acc_25: 1.0000 - dense_1_acc_26: 1.0000 - dense_1_acc_27: 1.0000 - dense_1_acc_28: 1.0000 - dense_1_acc_29: 0.0167
# Epoch 52/100
# 60/60 [==============================] - 0s 2ms/step - loss: 12.3990 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.0667 - dense_1_acc_1: 0.4833 - dense_1_acc_2: 0.8000 - dense_1_acc_3: 0.9333 - dense_1_acc_4: 0.9833 - dense_1_acc_5: 0.9667 - dense_1_acc_6: 1.0000 - dense_1_acc_7: 0.9833 - dense_1_acc_8: 1.0000 - dense_1_acc_9: 1.0000 - dense_1_acc_10: 1.0000 - dense_1_acc_11: 1.0000 - dense_1_acc_12: 1.0000 - dense_1_acc_13: 1.0000 - dense_1_acc_14: 1.0000 - dense_1_acc_15: 1.0000 - dense_1_acc_16: 1.0000 - dense_1_acc_17: 1.0000 - dense_1_acc_18: 1.0000 - dense_1_acc_19: 1.0000 - dense_1_acc_20: 1.0000 - dense_1_acc_21: 1.0000 - dense_1_acc_22: 1.0000 - dense_1_acc_23: 1.0000 - dense_1_acc_24: 1.0000 - dense_1_acc_25: 1.0000 - dense_1_acc_26: 1.0000 - dense_1_acc_27: 1.0000 - dense_1_acc_28: 1.0000 - dense_1_acc_29: 0.0167
# Epoch 53/100
# 60/60 [==============================] - 0s 2ms/step - loss: 12.0090 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.0667 - dense_1_acc_1: 0.4833 - dense_1_acc_2: 0.8000 - dense_1_acc_3: 0.9333 - dense_1_acc_4: 0.9833 - dense_1_acc_5: 0.9667 - dense_1_acc_6: 1.0000 - dense_1_acc_7: 0.9833 - dense_1_acc_8: 1.0000 - dense_1_acc_9: 1.0000 - dense_1_acc_10: 1.0000 - dense_1_acc_11: 1.0000 - dense_1_acc_12: 1.0000 - dense_1_acc_13: 1.0000 - dense_1_acc_14: 1.0000 - dense_1_acc_15: 1.0000 - dense_1_acc_16: 1.0000 - dense_1_acc_17: 1.0000 - dense_1_acc_18: 1.0000 - dense_1_acc_19: 1.0000 - dense_1_acc_20: 1.0000 - dense_1_acc_21: 1.0000 - dense_1_acc_22: 1.0000 - dense_1_acc_23: 1.0000 - dense_1_acc_24: 1.0000 - dense_1_acc_25: 1.0000 - dense_1_acc_26: 1.0000 - dense_1_acc_27: 1.0000 - dense_1_acc_28: 1.0000 - dense_1_acc_29: 0.0167
# Epoch 54/100
# 60/60 [==============================] - 0s 2ms/step - loss: 11.6471 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.1000 - dense_1_acc_1: 0.5000 - dense_1_acc_2: 0.8000 - dense_1_acc_3: 0.9333 - dense_1_acc_4: 0.9833 - dense_1_acc_5: 0.9667 - dense_1_acc_6: 1.0000 - dense_1_acc_7: 0.9833 - dense_1_acc_8: 1.0000 - dense_1_acc_9: 1.0000 - dense_1_acc_10: 1.0000 - dense_1_acc_11: 1.0000 - dense_1_acc_12: 1.0000 - dense_1_acc_13: 1.0000 - dense_1_acc_14: 1.0000 - dense_1_acc_15: 1.0000 - dense_1_acc_16: 1.0000 - dense_1_acc_17: 1.0000 - dense_1_acc_18: 1.0000 - dense_1_acc_19: 1.0000 - dense_1_acc_20: 1.0000 - dense_1_acc_21: 1.0000 - dense_1_acc_22: 1.0000 - dense_1_acc_23: 1.0000 - dense_1_acc_24: 1.0000 - dense_1_acc_25: 1.0000 - dense_1_acc_26: 1.0000 - dense_1_acc_27: 1.0000 - dense_1_acc_28: 1.0000 - dense_1_acc_29: 0.0167
# Epoch 55/100
# 60/60 [==============================] - 0s 2ms/step - loss: 11.3195 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.1000 - dense_1_acc_1: 0.5000 - dense_1_acc_2: 0.8000 - dense_1_acc_3: 0.9333 - dense_1_acc_4: 0.9833 - dense_1_acc_5: 0.9667 - dense_1_acc_6: 1.0000 - dense_1_acc_7: 0.9833 - dense_1_acc_8: 1.0000 - dense_1_acc_9: 1.0000 - dense_1_acc_10: 1.0000 - dense_1_acc_11: 1.0000 - dense_1_acc_12: 1.0000 - dense_1_acc_13: 1.0000 - dense_1_acc_14: 1.0000 - dense_1_acc_15: 1.0000 - dense_1_acc_16: 1.0000 - dense_1_acc_17: 1.0000 - dense_1_acc_18: 1.0000 - dense_1_acc_19: 1.0000 - dense_1_acc_20: 1.0000 - dense_1_acc_21: 1.0000 - dense_1_acc_22: 1.0000 - dense_1_acc_23: 1.0000 - dense_1_acc_24: 1.0000 - dense_1_acc_25: 1.0000 - dense_1_acc_26: 1.0000 - dense_1_acc_27: 1.0000 - dense_1_acc_28: 1.0000 - dense_1_acc_29: 0.0167
# Epoch 56/100
# 60/60 [==============================] - 0s 2ms/step - loss: 11.0046 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.1000 - dense_1_acc_1: 0.5000 - dense_1_acc_2: 0.8167 - dense_1_acc_3: 0.9500 - dense_1_acc_4: 0.9833 - dense_1_acc_5: 0.9667 - dense_1_acc_6: 1.0000 - dense_1_acc_7: 0.9833 - dense_1_acc_8: 1.0000 - dense_1_acc_9: 1.0000 - dense_1_acc_10: 1.0000 - dense_1_acc_11: 1.0000 - dense_1_acc_12: 1.0000 - dense_1_acc_13: 1.0000 - dense_1_acc_14: 1.0000 - dense_1_acc_15: 1.0000 - dense_1_acc_16: 1.0000 - dense_1_acc_17: 1.0000 - dense_1_acc_18: 1.0000 - dense_1_acc_19: 1.0000 - dense_1_acc_20: 1.0000 - dense_1_acc_21: 1.0000 - dense_1_acc_22: 1.0000 - dense_1_acc_23: 1.0000 - dense_1_acc_24: 1.0000 - dense_1_acc_25: 1.0000 - dense_1_acc_26: 1.0000 - dense_1_acc_27: 1.0000 - dense_1_acc_28: 1.0000 - dense_1_acc_29: 0.0167
# Epoch 57/100
# ...
# Epoch 83/100
# 60/60 [==============================] - 0s 2ms/step - loss: 7.2133 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.1000 - dense_1_acc_1: 0.6167 - dense_1_acc_2: 0.8833 - dense_1_acc_3: 1.0000 - dense_1_acc_4: 0.9833 - dense_1_acc_5: 1.0000 - dense_1_acc_6: 1.0000 - dense_1_acc_7: 1.0000 - dense_1_acc_8: 1.0000 - dense_1_acc_9: 1.0000 - dense_1_acc_10: 1.0000 - dense_1_acc_11: 1.0000 - dense_1_acc_12: 1.0000 - dense_1_acc_13: 1.0000 - dense_1_acc_14: 1.0000 - dense_1_acc_15: 1.0000 - dense_1_acc_16: 1.0000 - dense_1_acc_17: 1.0000 - dense_1_acc_18: 1.0000 - dense_1_acc_19: 1.0000 - dense_1_acc_20: 1.0000 - dense_1_acc_21: 1.0000 - dense_1_acc_22: 1.0000 - dense_1_acc_23: 1.0000 - dense_1_acc_24: 1.0000 - dense_1_acc_25: 1.0000 - dense_1_acc_26: 1.0000 - dense_1_acc_27: 1.0000 - dense_1_acc_28: 1.0000 - dense_1_acc_29: 0.0167
# Epoch 84/100
# 60/60 [==============================] - 0s 2ms/step - loss: 7.1494 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.1000 - dense_1_acc_1: 0.6167 - dense_1_acc_2: 0.8833 - dense_1_acc_3: 1.0000 - dense_1_acc_4: 0.9833 - dense_1_acc_5: 1.0000 - dense_1_acc_6: 1.0000 - dense_1_acc_7: 1.0000 - dense_1_acc_8: 1.0000 - dense_1_acc_9: 1.0000 - dense_1_acc_10: 1.0000 - dense_1_acc_11: 1.0000 - dense_1_acc_12: 1.0000 - dense_1_acc_13: 1.0000 - dense_1_acc_14: 1.0000 - dense_1_acc_15: 1.0000 - dense_1_acc_16: 1.0000 - dense_1_acc_17: 1.0000 - dense_1_acc_18: 1.0000 - dense_1_acc_19: 1.0000 - dense_1_acc_20: 1.0000 - dense_1_acc_21: 1.0000 - dense_1_acc_22: 1.0000 - dense_1_acc_23: 1.0000 - dense_1_acc_24: 1.0000 - dense_1_acc_25: 1.0000 - dense_1_acc_26: 1.0000 - dense_1_acc_27: 1.0000 - dense_1_acc_28: 1.0000 - dense_1_acc_29: 0.0167
# Epoch 85/100
# 60/60 [==============================] - 0s 2ms/step - loss: 7.0876 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.1000 - dense_1_acc_1: 0.6167 - dense_1_acc_2: 0.8833 - dense_1_acc_3: 1.0000 - dense_1_acc_4: 0.9833 - dense_1_acc_5: 1.0000 - dense_1_acc_6: 1.0000 - dense_1_acc_7: 1.0000 - dense_1_acc_8: 1.0000 - dense_1_acc_9: 1.0000 - dense_1_acc_10: 1.0000 - dense_1_acc_11: 1.0000 - dense_1_acc_12: 1.0000 - dense_1_acc_13: 1.0000 - dense_1_acc_14: 1.0000 - dense_1_acc_15: 1.0000 - dense_1_acc_16: 1.0000 - dense_1_acc_17: 1.0000 - dense_1_acc_18: 1.0000 - dense_1_acc_19: 1.0000 - dense_1_acc_20: 1.0000 - dense_1_acc_21: 1.0000 - dense_1_acc_22: 1.0000 - dense_1_acc_23: 1.0000 - dense_1_acc_24: 1.0000 - dense_1_acc_25: 1.0000 - dense_1_acc_26: 1.0000 - dense_1_acc_27: 1.0000 - dense_1_acc_28: 1.0000 - dense_1_acc_29: 0.0167
# Epoch 86/100
# 60/60 [==============================] - 0s 2ms/step - loss: 7.0282 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.1000 - dense_1_acc_1: 0.6167 - dense_1_acc_2: 0.8833 - dense_1_acc_3: 1.0000 - dense_1_acc_4: 0.9833 - dense_1_acc_5: 1.0000 - dense_1_acc_6: 1.0000 - dense_1_acc_7: 1.0000 - dense_1_acc_8: 1.0000 - dense_1_acc_9: 1.0000 - dense_1_acc_10: 1.0000 - dense_1_acc_11: 1.0000 - dense_1_acc_12: 1.0000 - dense_1_acc_13: 1.0000 - dense_1_acc_14: 1.0000 - dense_1_acc_15: 1.0000 - dense_1_acc_16: 1.0000 - dense_1_acc_17: 1.0000 - dense_1_acc_18: 1.0000 - dense_1_acc_19: 1.0000 - dense_1_acc_20: 1.0000 - dense_1_acc_21: 1.0000 - dense_1_acc_22: 1.0000 - dense_1_acc_23: 1.0000 - dense_1_acc_24: 1.0000 - dense_1_acc_25: 1.0000 - dense_1_acc_26: 1.0000 - dense_1_acc_27: 1.0000 - dense_1_acc_28: 1.0000 - dense_1_acc_29: 0.0167
# Epoch 87/100
# 60/60 [==============================] - 0s 2ms/step - loss: 6.9718 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.1000 - dense_1_acc_1: 0.6167 - dense_1_acc_2: 0.8833 - dense_1_acc_3: 1.0000 - dense_1_acc_4: 0.9833 - dense_1_acc_5: 1.0000 - dense_1_acc_6: 1.0000 - dense_1_acc_7: 1.0000 - dense_1_acc_8: 1.0000 - dense_1_acc_9: 1.0000 - dense_1_acc_10: 1.0000 - dense_1_acc_11: 1.0000 - dense_1_acc_12: 1.0000 - dense_1_acc_13: 1.0000 - dense_1_acc_14: 1.0000 - dense_1_acc_15: 1.0000 - dense_1_acc_16: 1.0000 - dense_1_acc_17: 1.0000 - dense_1_acc_18: 1.0000 - dense_1_acc_19: 1.0000 - dense_1_acc_20: 1.0000 - dense_1_acc_21: 1.0000 - dense_1_acc_22: 1.0000 - dense_1_acc_23: 1.0000 - dense_1_acc_24: 1.0000 - dense_1_acc_25: 1.0000 - dense_1_acc_26: 1.0000 - dense_1_acc_27: 1.0000 - dense_1_acc_28: 1.0000 - dense_1_acc_29: 0.0167
# Epoch 88/100
# 60/60 [==============================] - 0s 2ms/step - loss: 6.9156 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.1000 - dense_1_acc_1: 0.6167 - dense_1_acc_2: 0.8833 - dense_1_acc_3: 1.0000 - dense_1_acc_4: 0.9833 - dense_1_acc_5: 1.0000 - dense_1_acc_6: 1.0000 - dense_1_acc_7: 1.0000 - dense_1_acc_8: 1.0000 - dense_1_acc_9: 1.0000 - dense_1_acc_10: 1.0000 - dense_1_acc_11: 1.0000 - dense_1_acc_12: 1.0000 - dense_1_acc_13: 1.0000 - dense_1_acc_14: 1.0000 - dense_1_acc_15: 1.0000 - dense_1_acc_16: 1.0000 - dense_1_acc_17: 1.0000 - dense_1_acc_18: 1.0000 - dense_1_acc_19: 1.0000 - dense_1_acc_20: 1.0000 - dense_1_acc_21: 1.0000 - dense_1_acc_22: 1.0000 - dense_1_acc_23: 1.0000 - dense_1_acc_24: 1.0000 - dense_1_acc_25: 1.0000 - dense_1_acc_26: 1.0000 - dense_1_acc_27: 1.0000 - dense_1_acc_28: 1.0000 - dense_1_acc_29: 0.0167
# Epoch 89/100
# 60/60 [==============================] - 0s 2ms/step - loss: 6.8608 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.1000 - dense_1_acc_1: 0.6167 - dense_1_acc_2: 0.8833 - dense_1_acc_3: 1.0000 - dense_1_acc_4: 0.9833 - dense_1_acc_5: 1.0000 - dense_1_acc_6: 1.0000 - dense_1_acc_7: 1.0000 - dense_1_acc_8: 1.0000 - dense_1_acc_9: 1.0000 - dense_1_acc_10: 1.0000 - dense_1_acc_11: 1.0000 - dense_1_acc_12: 1.0000 - dense_1_acc_13: 1.0000 - dense_1_acc_14: 1.0000 - dense_1_acc_15: 1.0000 - dense_1_acc_16: 1.0000 - dense_1_acc_17: 1.0000 - dense_1_acc_18: 1.0000 - dense_1_acc_19: 1.0000 - dense_1_acc_20: 1.0000 - dense_1_acc_21: 1.0000 - dense_1_acc_22: 1.0000 - dense_1_acc_23: 1.0000 - dense_1_acc_24: 1.0000 - dense_1_acc_25: 1.0000 - dense_1_acc_26: 1.0000 - dense_1_acc_27: 1.0000 - dense_1_acc_28: 1.0000 - dense_1_acc_29: 0.0167
# Epoch 90/100
# 60/60 [==============================] - 0s 2ms/step - loss: 6.8100 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.1000 - dense_1_acc_1: 0.6167 - dense_1_acc_2: 0.8833 - dense_1_acc_3: 1.0000 - dense_1_acc_4: 0.9833 - dense_1_acc_5: 1.0000 - dense_1_acc_6: 1.0000 - dense_1_acc_7: 1.0000 - dense_1_acc_8: 1.0000 - dense_1_acc_9: 1.0000 - dense_1_acc_10: 1.0000 - dense_1_acc_11: 1.0000 - dense_1_acc_12: 1.0000 - dense_1_acc_13: 1.0000 - dense_1_acc_14: 1.0000 - dense_1_acc_15: 1.0000 - dense_1_acc_16: 1.0000 - dense_1_acc_17: 1.0000 - dense_1_acc_18: 1.0000 - dense_1_acc_19: 1.0000 - dense_1_acc_20: 1.0000 - dense_1_acc_21: 1.0000 - dense_1_acc_22: 1.0000 - dense_1_acc_23: 1.0000 - dense_1_acc_24: 1.0000 - dense_1_acc_25: 1.0000 - dense_1_acc_26: 1.0000 - dense_1_acc_27: 1.0000 - dense_1_acc_28: 1.0000 - dense_1_acc_29: 0.0167
# Epoch 91/100
# 60/60 [==============================] - 0s 1ms/step - loss: 6.7603 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.1000 - dense_1_acc_1: 0.6167 - dense_1_acc_2: 0.8833 - dense_1_acc_3: 1.0000 - dense_1_acc_4: 0.9833 - dense_1_acc_5: 1.0000 - dense_1_acc_6: 1.0000 - dense_1_acc_7: 1.0000 - dense_1_acc_8: 1.0000 - dense_1_acc_9: 1.0000 - dense_1_acc_10: 1.0000 - dense_1_acc_11: 1.0000 - dense_1_acc_12: 1.0000 - dense_1_acc_13: 1.0000 - dense_1_acc_14: 1.0000 - dense_1_acc_15: 1.0000 - dense_1_acc_16: 1.0000 - dense_1_acc_17: 1.0000 - dense_1_acc_18: 1.0000 - dense_1_acc_19: 1.0000 - dense_1_acc_20: 1.0000 - dense_1_acc_21: 1.0000 - dense_1_acc_22: 1.0000 - dense_1_acc_23: 1.0000 - dense_1_acc_24: 1.0000 - dense_1_acc_25: 1.0000 - dense_1_acc_26: 1.0000 - dense_1_acc_27: 1.0000 - dense_1_acc_28: 1.0000 - dense_1_acc_29: 0.0167
# Epoch 92/100
# 60/60 [==============================] - 0s 2ms/step - loss: 6.7109 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.1000 - dense_1_acc_1: 0.6167 - dense_1_acc_2: 0.8833 - dense_1_acc_3: 1.0000 - dense_1_acc_4: 1.0000 - dense_1_acc_5: 1.0000 - dense_1_acc_6: 1.0000 - dense_1_acc_7: 1.0000 - dense_1_acc_8: 1.0000 - dense_1_acc_9: 1.0000 - dense_1_acc_10: 1.0000 - dense_1_acc_11: 1.0000 - dense_1_acc_12: 1.0000 - dense_1_acc_13: 1.0000 - dense_1_acc_14: 1.0000 - dense_1_acc_15: 1.0000 - dense_1_acc_16: 1.0000 - dense_1_acc_17: 1.0000 - dense_1_acc_18: 1.0000 - dense_1_acc_19: 1.0000 - dense_1_acc_20: 1.0000 - dense_1_acc_21: 1.0000 - dense_1_acc_22: 1.0000 - dense_1_acc_23: 1.0000 - dense_1_acc_24: 1.0000 - dense_1_acc_25: 1.0000 - dense_1_acc_26: 1.0000 - dense_1_acc_27: 1.0000 - dense_1_acc_28: 1.0000 - dense_1_acc_29: 0.0167
# Epoch 93/100
# 60/60 [==============================] - 0s 2ms/step - loss: 6.6647 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.1000 - dense_1_acc_1: 0.6333 - dense_1_acc_2: 0.8833 - dense_1_acc_3: 1.0000 - dense_1_acc_4: 1.0000 - dense_1_acc_5: 1.0000 - dense_1_acc_6: 1.0000 - dense_1_acc_7: 1.0000 - dense_1_acc_8: 1.0000 - dense_1_acc_9: 1.0000 - dense_1_acc_10: 1.0000 - dense_1_acc_11: 1.0000 - dense_1_acc_12: 1.0000 - dense_1_acc_13: 1.0000 - dense_1_acc_14: 1.0000 - dense_1_acc_15: 1.0000 - dense_1_acc_16: 1.0000 - dense_1_acc_17: 1.0000 - dense_1_acc_18: 1.0000 - dense_1_acc_19: 1.0000 - dense_1_acc_20: 1.0000 - dense_1_acc_21: 1.0000 - dense_1_acc_22: 1.0000 - dense_1_acc_23: 1.0000 - dense_1_acc_24: 1.0000 - dense_1_acc_25: 1.0000 - dense_1_acc_26: 1.0000 - dense_1_acc_27: 1.0000 - dense_1_acc_28: 1.0000 - dense_1_acc_29: 0.0167
# Epoch 94/100
# 60/60 [==============================] - 0s 2ms/step - loss: 6.6192 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.1000 - dense_1_acc_1: 0.6333 - dense_1_acc_2: 0.8833 - dense_1_acc_3: 1.0000 - dense_1_acc_4: 1.0000 - dense_1_acc_5: 1.0000 - dense_1_acc_6: 1.0000 - dense_1_acc_7: 1.0000 - dense_1_acc_8: 1.0000 - dense_1_acc_9: 1.0000 - dense_1_acc_10: 1.0000 - dense_1_acc_11: 1.0000 - dense_1_acc_12: 1.0000 - dense_1_acc_13: 1.0000 - dense_1_acc_14: 1.0000 - dense_1_acc_15: 1.0000 - dense_1_acc_16: 1.0000 - dense_1_acc_17: 1.0000 - dense_1_acc_18: 1.0000 - dense_1_acc_19: 1.0000 - dense_1_acc_20: 1.0000 - dense_1_acc_21: 1.0000 - dense_1_acc_22: 1.0000 - dense_1_acc_23: 1.0000 - dense_1_acc_24: 1.0000 - dense_1_acc_25: 1.0000 - dense_1_acc_26: 1.0000 - dense_1_acc_27: 1.0000 - dense_1_acc_28: 1.0000 - dense_1_acc_29: 0.0167
# Epoch 95/100
# 60/60 [==============================] - 0s 2ms/step - loss: 6.5743 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.1000 - dense_1_acc_1: 0.6333 - dense_1_acc_2: 0.9000 - dense_1_acc_3: 1.0000 - dense_1_acc_4: 1.0000 - dense_1_acc_5: 1.0000 - dense_1_acc_6: 1.0000 - dense_1_acc_7: 1.0000 - dense_1_acc_8: 1.0000 - dense_1_acc_9: 1.0000 - dense_1_acc_10: 1.0000 - dense_1_acc_11: 1.0000 - dense_1_acc_12: 1.0000 - dense_1_acc_13: 1.0000 - dense_1_acc_14: 1.0000 - dense_1_acc_15: 1.0000 - dense_1_acc_16: 1.0000 - dense_1_acc_17: 1.0000 - dense_1_acc_18: 1.0000 - dense_1_acc_19: 1.0000 - dense_1_acc_20: 1.0000 - dense_1_acc_21: 1.0000 - dense_1_acc_22: 1.0000 - dense_1_acc_23: 1.0000 - dense_1_acc_24: 1.0000 - dense_1_acc_25: 1.0000 - dense_1_acc_26: 1.0000 - dense_1_acc_27: 1.0000 - dense_1_acc_28: 1.0000 - dense_1_acc_29: 0.0167
# Epoch 96/100
# 60/60 [==============================] - 0s 2ms/step - loss: 6.5319 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.1000 - dense_1_acc_1: 0.6333 - dense_1_acc_2: 0.9000 - dense_1_acc_3: 1.0000 - dense_1_acc_4: 1.0000 - dense_1_acc_5: 1.0000 - dense_1_acc_6: 1.0000 - dense_1_acc_7: 1.0000 - dense_1_acc_8: 1.0000 - dense_1_acc_9: 1.0000 - dense_1_acc_10: 1.0000 - dense_1_acc_11: 1.0000 - dense_1_acc_12: 1.0000 - dense_1_acc_13: 1.0000 - dense_1_acc_14: 1.0000 - dense_1_acc_15: 1.0000 - dense_1_acc_16: 1.0000 - dense_1_acc_17: 1.0000 - dense_1_acc_18: 1.0000 - dense_1_acc_19: 1.0000 - dense_1_acc_20: 1.0000 - dense_1_acc_21: 1.0000 - dense_1_acc_22: 1.0000 - dense_1_acc_23: 1.0000 - dense_1_acc_24: 1.0000 - dense_1_acc_25: 1.0000 - dense_1_acc_26: 1.0000 - dense_1_acc_27: 1.0000 - dense_1_acc_28: 1.0000 - dense_1_acc_29: 0.0167
# Epoch 97/100
# 60/60 [==============================] - 0s 2ms/step - loss: 6.4892 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.1000 - dense_1_acc_1: 0.6333 - dense_1_acc_2: 0.9000 - dense_1_acc_3: 1.0000 - dense_1_acc_4: 1.0000 - dense_1_acc_5: 1.0000 - dense_1_acc_6: 1.0000 - dense_1_acc_7: 1.0000 - dense_1_acc_8: 1.0000 - dense_1_acc_9: 1.0000 - dense_1_acc_10: 1.0000 - dense_1_acc_11: 1.0000 - dense_1_acc_12: 1.0000 - dense_1_acc_13: 1.0000 - dense_1_acc_14: 1.0000 - dense_1_acc_15: 1.0000 - dense_1_acc_16: 1.0000 - dense_1_acc_17: 1.0000 - dense_1_acc_18: 1.0000 - dense_1_acc_19: 1.0000 - dense_1_acc_20: 1.0000 - dense_1_acc_21: 1.0000 - dense_1_acc_22: 1.0000 - dense_1_acc_23: 1.0000 - dense_1_acc_24: 1.0000 - dense_1_acc_25: 1.0000 - dense_1_acc_26: 1.0000 - dense_1_acc_27: 1.0000 - dense_1_acc_28: 1.0000 - dense_1_acc_29: 0.0167
# Epoch 98/100
# 60/60 [==============================] - 0s 2ms/step - loss: 6.4510 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.1000 - dense_1_acc_1: 0.6333 - dense_1_acc_2: 0.9000 - dense_1_acc_3: 1.0000 - dense_1_acc_4: 1.0000 - dense_1_acc_5: 1.0000 - dense_1_acc_6: 1.0000 - dense_1_acc_7: 1.0000 - dense_1_acc_8: 1.0000 - dense_1_acc_9: 1.0000 - dense_1_acc_10: 1.0000 - dense_1_acc_11: 1.0000 - dense_1_acc_12: 1.0000 - dense_1_acc_13: 1.0000 - dense_1_acc_14: 1.0000 - dense_1_acc_15: 1.0000 - dense_1_acc_16: 1.0000 - dense_1_acc_17: 1.0000 - dense_1_acc_18: 1.0000 - dense_1_acc_19: 1.0000 - dense_1_acc_20: 1.0000 - dense_1_acc_21: 1.0000 - dense_1_acc_22: 1.0000 - dense_1_acc_23: 1.0000 - dense_1_acc_24: 1.0000 - dense_1_acc_25: 1.0000 - dense_1_acc_26: 1.0000 - dense_1_acc_27: 1.0000 - dense_1_acc_28: 1.0000 - dense_1_acc_29: 0.0167
# Epoch 99/100
# 60/60 [==============================] - 0s 2ms/step - loss: 6.4116 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.1000 - dense_1_acc_1: 0.6333 - dense_1_acc_2: 0.9000 - dense_1_acc_3: 1.0000 - dense_1_acc_4: 1.0000 - dense_1_acc_5: 1.0000 - dense_1_acc_6: 1.0000 - dense_1_acc_7: 1.0000 - dense_1_acc_8: 1.0000 - dense_1_acc_9: 1.0000 - dense_1_acc_10: 1.0000 - dense_1_acc_11: 1.0000 - dense_1_acc_12: 1.0000 - dense_1_acc_13: 1.0000 - dense_1_acc_14: 1.0000 - dense_1_acc_15: 1.0000 - dense_1_acc_16: 1.0000 - dense_1_acc_17: 1.0000 - dense_1_acc_18: 1.0000 - dense_1_acc_19: 1.0000 - dense_1_acc_20: 1.0000 - dense_1_acc_21: 1.0000 - dense_1_acc_22: 1.0000 - dense_1_acc_23: 1.0000 - dense_1_acc_24: 1.0000 - dense_1_acc_25: 1.0000 - dense_1_acc_26: 1.0000 - dense_1_acc_27: 1.0000 - dense_1_acc_28: 1.0000 - dense_1_acc_29: 0.0167
# Epoch 100/100
# 60/60 [==============================] - 0s 2ms/step - loss: 6.3733 - dense_1_loss: 0.0000e+00 - dense_1_acc: 0.1000 - dense_1_acc_1: 0.6333 - dense_1_acc_2: 0.9000 - dense_1_acc_3: 1.0000 - dense_1_acc_4: 1.0000 - dense_1_acc_5: 1.0000 - dense_1_acc_6: 1.0000 - dense_1_acc_7: 1.0000 - dense_1_acc_8: 1.0000 - dense_1_acc_9: 1.0000 - dense_1_acc_10: 1.0000 - dense_1_acc_11: 1.0000 - dense_1_acc_12: 1.0000 - dense_1_acc_13: 1.0000 - dense_1_acc_14: 1.0000 - dense_1_acc_15: 1.0000 - dense_1_acc_16: 1.0000 - dense_1_acc_17: 1.0000 - dense_1_acc_18: 1.0000 - dense_1_acc_19: 1.0000 - dense_1_acc_20: 1.0000 - dense_1_acc_21: 1.0000 - dense_1_acc_22: 1.0000 - dense_1_acc_23: 1.0000 - dense_1_acc_24: 1.0000 - dense_1_acc_25: 1.0000 - dense_1_acc_26: 1.0000 - dense_1_acc_27: 1.0000 - dense_1_acc_28: 1.0000 - dense_1_acc_29: 0.0167

# %% [markdown]
# You should see the model loss going down. Now that you have trained a model, lets go on the the final section to implement an inference algorithm, and generate some music!

# %% [markdown]
# ## 3 - Generating music
#
# You now have a trained model which has learned the patterns of the jazz soloist. Lets now use this model to synthesize new music.
#
# #### 3.1 - Predicting & Sampling
#
# We will implement the function below to sample a sequence of musical values.
#
# Step 2.A: Use `LSTM_Cell`, which inputs the previous step's `c` and `a` to generate the current step's `c` and `a`.
#
# Step 2.B: Use `densor` (defined previously) to compute a softmax on `a` to get the output for the current step.
#
# Step 2.C: Save the output you have just generated by appending it to `outputs`.
#
# Step 2.D: Sample x to the be "out"'s one-hot version (the prediction) so that you can pass it to the next LSTM's step.

# %%
def music_inference_model(LSTM_cell, densor, n_values = 78, n_a = 64, Ty = 100):
    """
    Uses the trained "LSTM_cell" and "densor" from model() to generate a sequence of values.
    
    Arguments:
    LSTM_cell -- the trained "LSTM_cell" from model(), Keras layer object
    densor -- the trained "densor" from model(), Keras layer object
    n_values -- integer, umber of unique values
    n_a -- number of units in the LSTM_cell
    Ty -- integer, number of time steps to generate
    
    Returns:
    inference_model -- Keras model instance
    """
    
    x0 = Input(shape=(1, n_values))
    a0 = Input(shape=(n_a,), name='a0')
    c0 = Input(shape=(n_a,), name='c0')
    a = a0
    c = c0
    x = x0

    outputs = []
    
    for t in range(Ty):
        
        a, _, c = LSTM_cell(x, initial_state=[a, c])
        out = densor(a)
        outputs.append(out)
        
        # Select the next value according to "out", and set "x" to be the one-hot representation of the
        # selected value, which will be passed as the input to LSTM_cell on the next step. 
        x = Lambda(one_hot)(out)
        
    inference_model = Model([x0, a0, c0],outputs = outputs)
    
    return inference_model

# %% [markdown]
# Run the cell below to define your inference model. This model is hard coded to generate 50 values.

# %%
inference_model = music_inference_model(LSTM_cell, densor, n_values = 78, n_a = 64, Ty = 50)

# %% [markdown]
# Finally, this creates the zero-valued vectors you will use to initialize `x` and the LSTM state variables `a` and `c`.

# %%
x_initializer = np.zeros((1, 1, 78))
a_initializer = np.zeros((1, n_a))
c_initializer = np.zeros((1, n_a))

# %% [markdown]
# This function takes many arguments including the inputs [x_initializer, a_initializer, c_initializer]. In order to predict the output corresponding to this input.
# 1. Use your inference model to predict an output given your set of inputs. The output `pred` should be a list of length $T_y$ where each element is a numpy-array of shape (1, n_values).
# 2. Convert `pred` into a numpy array of $T_y$ indices. Each index corresponds is computed by taking the `argmax` of an element of the `pred` list. [Hint](https://docs.scipy.org/doc/numpy/reference/generated/numpy.argmax.html).
# 3. Convert the indices into their one-hot vector representations. [Hint](https://keras.io/utils/#to_categorical).

# %%
def predict_and_sample(inference_model, x_initializer = x_initializer, a_initializer = a_initializer, 
                       c_initializer = c_initializer):
    """
    Predicts the next value of values using the inference model.
    
    Arguments:
    inference_model -- Keras model instance for inference time
    x_initializer -- numpy array of shape (1, 1, 78), one-hot vector initializing the values generation
    a_initializer -- numpy array of shape (1, n_a), initializing the hidden state of the LSTM_cell
    c_initializer -- numpy array of shape (1, n_a), initializing the cell state of the LSTM_cel
    
    Returns:
    results -- numpy-array of shape (Ty, 78), matrix of one-hot vectors representing the values generated
    indices -- numpy-array of shape (Ty, 1), matrix of indices representing the values generated
    """
    
    # Use inference model to predict an output sequence given x_initializer, a_initializer and c_initializer.
    pred = inference_model.predict([x_initializer,a_initializer,c_initializer])
    # Convert "pred" into an np.array() of indices with the maximum probabilities
    indices = np.argmax(pred, axis = 2)
    # Convert indices to one-hot vectors, the shape of the results should be (1, )
    results = to_categorical(indices)
    
    return results, indices

# %%
results, indices = predict_and_sample(inference_model, x_initializer, a_initializer, c_initializer)
print("list(indices[12:18]) =", list(indices[12:18]))
# Out:
# list(indices[12:18]) = [array([35]), array([34]), array([47]), array([5]), array([35]), array([34])]

# %% [markdown]
# #### 3.3 - Generate music
#
#
# Lets make some music!

# %% [markdown]
# Run the following cell to generate music and record it into your `out_stream`. This can take a couple of minutes.

# %%
out_stream = generate_music(inference_model)
# Out:
# Predicting new values for different set of chords.
# Generated 50 sounds using the predicted values for the set of chords ("1") and after pruning
# Generated 51 sounds using the predicted values for the set of chords ("2") and after pruning
# Generated 51 sounds using the predicted values for the set of chords ("3") and after pruning
# Generated 51 sounds using the predicted values for the set of chords ("4") and after pruning
# Generated 51 sounds using the predicted values for the set of chords ("5") and after pruning
# Your generated music is saved in output/my_music.midi

# %% [markdown]
# # 3. Output

# %%
IPython.display.Audio('./output/my_music2.mp3')
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# **References**
#
# The ideas presented in this notebook came primarily from three computational music papers cited below. The implementation here also took significant inspiration and used many components from Ji-Sung Kim's github repository.
#
# - Ji-Sung Kim, 2016, [deepjazz](https://github.com/jisungk/deepjazz)
# - Jon Gillick, Kevin Tang and Robert Keller, 2009. [Learning Jazz Grammars](http://ai.stanford.edu/~kdtang/papers/smc09-jazzgrammar.pdf)
# - Robert Keller and David Morrison, 2007, [A Grammatical Approach to Automatic Improvisation](http://smc07.uoa.gr/SMC07%20Proceedings/SMC07%20Paper%2055.pdf)
# - François Pachet, 1999, [Surprising Harmonies](http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.5.7473&rep=rep1&type=pdf)
